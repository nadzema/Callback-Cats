# %%
import pandas as pd 
import pymongo
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.mlb_db
collection = db.stats

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Driver [C:\Users\lundi\.wdm\drivers\chromedriver\win32\89.0.4389.23\chromedriver.exe] found in cache

# %%
url = 'https://www.baseball-reference.com/leagues/MLB/2019-schedule.shtml'
browser.visit(url)

# %%
#creating the html 
html = browser.html

# %%
# create the soup 
soup = BeautifulSoup(html, 'html.parser')

# %%
# creating a list of dictionaries 
paragraphs = soup.find_all('p')
for paragraph in paragraphs:
     print(paragraph.text)
# Out:
# via Sports Logos.net
# About logos
# World Series Champion: Washington Nationals
# Minor Leagues
# Standings
# Schedule
# Fielding
# Batting
# Pitching
# Managers
# Fielding
# Batting
# Pitching
# Leaders & Awards
# Other
#
#  Seattle Mariners
#  (9)
#  @
#   Oakland Athletics
#  (7)
#      Boxscore
#
#     » 2019-03-20 Standings & Scores
#
#  Seattle Mariners
#  (5)
#  @
#   Oakland Athletics
#  (4)
#      Boxscore
#
#     » 2019-03-21 Standings & Scores
#
# Pittsburgh Pirates
#  (3)
#  @
#   Cincinnati Reds
#  (5)
#      Boxscore
#
#
# Chicago White Sox
#  (3)
#  @
#   Kansas City Royals
#  (5)
#      Boxscore
#
#
# Arizona D'Backs
#  (5)
#  @
#   Los Angeles Dodgers
#  (12)
#      Boxscore
#
#
#  Colorado Rockies
#  (6)
#  @
#   Miami Marlins
#  (3)
#      Boxscore
#
#
# St. Louis Cardinals
#  (4)
#  @
#   Milwaukee Brewers
#  (5)
#      Boxscore
#
#
# Cleveland Indians
#  (0)
#  @
#   Minnesota Twins
#  (2)
#      Boxscore
#
#
# Baltimore Orioles
#  (2)
#  @
#   New York Yankees
#  (7)
#      Boxscore
#
#
# Los Angeles Angels
#  (0)
#  @
#   Oakland Athletics
#  (4)
#      Boxscore
#
#
# Atlanta Braves
#  (4)
#  @
#   Philadelphia Phillies
#  (10)
#      Boxscore
#
#
# San Francisco Giants
#  (0)
#  @
#   San Diego Padres
#  (2)
#      Boxscore
#
#
# Boston Red Sox
#  (4)
#  @
#   Seattle Mariners
#  (12)
#      Boxscore
#
#
#  Houston Astros
#  (5)
#  @
#   Tampa Bay Rays
#  (1)
#      Boxscore
#
#
#  Chicago Cubs
#  (12)
#  @
#   Texas Rangers
#  (4)
#      Boxscore
#
#
#  Detroit Tigers
#  (2)
#  @
#   Toronto Blue Jays
#  (0)
#      Boxscore
#
#
#  New York Mets
#  (2)
#  @
#   Washington Nationals
#  (0)
#      Boxscore
#
#     » 2019-03-28 Standings & Scores
#
#  Arizona D'Backs
#  (5)
#  @
#   Los Angeles Dodgers
#  (4)
#      Boxscore
#
#
#  Colorado Rockies
#  (6)
#  @
#   Miami Marlins
#  (1)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (9)
#  @
#   Milwaukee Brewers
#  (5)
#      Boxscore
#
#
#  Los Angeles Angels
#  (6)
#  @
#   Oakland Athletics
#  (2)
#      Boxscore
#
#
# San Francisco Giants
#  (1)
#  @
#   San Diego Padres
#  (4)
#      Boxscore
#
#
#  Boston Red Sox
#  (7)
#  @
#   Seattle Mariners
#  (6)
#      Boxscore
#
#
# Houston Astros
#  (2)
#  @
#   Tampa Bay Rays
#  (4)
#      Boxscore
#
#
# Detroit Tigers
#  (0)
#  @
#   Toronto Blue Jays
#  (6)
#      Boxscore
#
#     » 2019-03-29 Standings & Scores
#
# Chicago White Sox
#  (6)
#  @
#   Kansas City Royals
#  (8)
#      Boxscore
#
#
# Arizona D'Backs
#  (5)
#  @
#   Los Angeles Dodgers
#  (18)
#      Boxscore
#
#
# Colorado Rockies
#  (3)
#  @
#   Miami Marlins
#  (7)
#      Boxscore
#
#
# St. Louis Cardinals
#  (2)
#  @
#   Milwaukee Brewers
#  (4)
#      Boxscore
#
#
#  Cleveland Indians
#  (2)
#  @
#   Minnesota Twins
#  (1)
#      Boxscore
#
#
#  Baltimore Orioles
#  (5)
#  @
#   New York Yankees
#  (3)
#      Boxscore
#
#
# Los Angeles Angels
#  (2)
#  @
#   Oakland Athletics
#  (4)
#      Boxscore
#
#
# Atlanta Braves
#  (6)
#  @
#   Philadelphia Phillies
#  (8)
#      Boxscore
#
#
#  San Francisco Giants
#  (3)
#  @
#   San Diego Padres
#  (2)
#      Boxscore
#
#
# Boston Red Sox
#  (5)
#  @
#   Seattle Mariners
#  (6)
#      Boxscore
#
#
# Houston Astros
#  (1)
#  @
#   Tampa Bay Rays
#  (3)
#      Boxscore
#
#
# Chicago Cubs
#  (6)
#  @
#   Texas Rangers
#  (8)
#      Boxscore
#
#
# Detroit Tigers
#  (0)
#  @
#   Toronto Blue Jays
#  (3)
#      Boxscore
#
#
#  New York Mets
#  (11)
#  @
#   Washington Nationals
#  (8)
#      Boxscore
#
#     » 2019-03-30 Standings & Scores
#
#  Pittsburgh Pirates
#  (5)
#  @
#   Cincinnati Reds
#  (0)
#      Boxscore
#
#
#  Chicago White Sox
#  (6)
#  @
#   Kansas City Royals
#  (3)
#      Boxscore
#
#
# Arizona D'Backs
#  (7)
#  @
#   Los Angeles Dodgers
#  (8)
#      Boxscore
#
#
# Colorado Rockies
#  (0)
#  @
#   Miami Marlins
#  (3)
#      Boxscore
#
#
# St. Louis Cardinals
#  (4)
#  @
#   Milwaukee Brewers
#  (5)
#      Boxscore
#
#
# Cleveland Indians
#  (3)
#  @
#   Minnesota Twins
#  (9)
#      Boxscore
#
#
#  Baltimore Orioles
#  (7)
#  @
#   New York Yankees
#  (5)
#      Boxscore
#
#
# Los Angeles Angels
#  (1)
#  @
#   Oakland Athletics
#  (2)
#      Boxscore
#
#
# Atlanta Braves
#  (1)
#  @
#   Philadelphia Phillies
#  (5)
#      Boxscore
#
#
# San Francisco Giants
#  (1)
#  @
#   San Diego Padres
#  (3)
#      Boxscore
#
#
# Boston Red Sox
#  (8)
#  @
#   Seattle Mariners
#  (10)
#      Boxscore
#
#
# Houston Astros
#  (1)
#  @
#   Tampa Bay Rays
#  (3)
#      Boxscore
#
#
# Chicago Cubs
#  (10)
#  @
#   Texas Rangers
#  (11)
#      Boxscore
#
#
#  Detroit Tigers
#  (4)
#  @
#   Toronto Blue Jays
#  (3)
#      Boxscore
#
#
# New York Mets
#  (5)
#  @
#   Washington Nationals
#  (6)
#      Boxscore
#
#     » 2019-03-31 Standings & Scores
#
# Chicago Cubs
#  (0)
#  @
#   Atlanta Braves
#  (8)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (4)
#  @
#   Cincinnati Reds
#  (3)
#      Boxscore
#
#
# Chicago White Sox
#  (3)
#  @
#   Cleveland Indians
#  (5)
#      Boxscore
#
#
#  San Francisco Giants
#  (4)
#  @
#   Los Angeles Dodgers
#  (2)
#      Boxscore
#
#
#  New York Mets
#  (7)
#  @
#   Miami Marlins
#  (3)
#      Boxscore
#
#
# Detroit Tigers
#  (1)
#  @
#   New York Yankees
#  (3)
#      Boxscore
#
#
# Boston Red Sox
#  (0)
#  @
#   Oakland Athletics
#  (7)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (6)
#  @
#   Pittsburgh Pirates
#  (5)
#      Boxscore
#
#
#  Arizona D'Backs
#  (10)
#  @
#   San Diego Padres
#  (3)
#      Boxscore
#
#
# Los Angeles Angels
#  (3)
#  @
#   Seattle Mariners
#  (6)
#      Boxscore
#
#
# Colorado Rockies
#  (1)
#  @
#   Tampa Bay Rays
#  (7)
#      Boxscore
#
#
#  Houston Astros
#  (2)
#  @
#   Texas Rangers
#  (1)
#      Boxscore
#
#
#  Baltimore Orioles
#  (6)
#  @
#   Toronto Blue Jays
#  (5)
#      Boxscore
#
#     » 2019-04-01 Standings & Scores
#
#  Milwaukee Brewers
#  (4)
#  @
#   Cincinnati Reds
#  (3)
#      Boxscore
#
#
#  Minnesota Twins
#  (5)
#  @
#   Kansas City Royals
#  (4)
#      Boxscore
#
#
# San Francisco Giants
#  (5)
#  @
#   Los Angeles Dodgers
#  (6)
#      Boxscore
#
#
#  New York Mets
#  (6)
#  @
#   Miami Marlins
#  (5)
#      Boxscore
#
#
#  Detroit Tigers
#  (3)
#  @
#   New York Yankees
#  (1)
#      Boxscore
#
#
# Boston Red Sox
#  (0)
#  @
#   Oakland Athletics
#  (1)
#      Boxscore
#
#
#  Arizona D'Backs
#  (8)
#  @
#   San Diego Padres
#  (5)
#      Boxscore
#
#
# Los Angeles Angels
#  (1)
#  @
#   Seattle Mariners
#  (2)
#      Boxscore
#
#
# Colorado Rockies
#  (0)
#  @
#   Tampa Bay Rays
#  (4)
#      Boxscore
#
#
# Houston Astros
#  (4)
#  @
#   Texas Rangers
#  (6)
#      Boxscore
#
#
#  Baltimore Orioles
#  (2)
#  @
#   Toronto Blue Jays
#  (1)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (8)
#  @
#   Washington Nationals
#  (2)
#      Boxscore
#
#     » 2019-04-02 Standings & Scores
#
# Chicago Cubs
#  (4)
#  @
#   Atlanta Braves
#  (6)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (1)
#  @
#   Cincinnati Reds
#  (0)
#      Boxscore
#
#
#  Chicago White Sox
#  (8)
#  @
#   Cleveland Indians
#  (3)
#      Boxscore
#
#
#  Minnesota Twins
#  (7)
#  @
#   Kansas City Royals
#  (6)
#      Boxscore
#
#
# San Francisco Giants
#  (3)
#  @
#   Los Angeles Dodgers
#  (5)
#      Boxscore
#
#
#  New York Mets
#  (6)
#  @
#   Miami Marlins
#  (4)
#      Boxscore
#
#
#  Detroit Tigers
#  (2)
#  @
#   New York Yankees
#  (1)
#      Boxscore
#
#
#  Boston Red Sox
#  (6)
#  @
#   Oakland Athletics
#  (3)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (5)
#  @
#   Pittsburgh Pirates
#  (4)
#      Boxscore
#
#
# Arizona D'Backs
#  (1)
#  @
#   San Diego Padres
#  (4)
#      Boxscore
#
#
#  Colorado Rockies
#  (1)
#  @
#   Tampa Bay Rays
#  (0)
#      Boxscore
#
#
# Houston Astros
#  (0)
#  @
#   Texas Rangers
#  (4)
#      Boxscore
#
#
# Baltimore Orioles
#  (3)
#  @
#   Toronto Blue Jays
#  (5)
#      Boxscore
#
#
# Philadelphia Phillies
#  (8)
#  @
#   Washington Nationals
#  (9)
#      Boxscore
#
#     » 2019-04-03 Standings & Scores
#
#  Texas Rangers
#  (11)
#  @
#   Los Angeles Angels
#  (4)
#      Boxscore
#
#
# Chicago Cubs
#  (4)
#  @
#   Atlanta Braves
#  (9)
#      Boxscore
#
#
#  New York Yankees
#  (8)
#  @
#   Baltimore Orioles
#  (4)
#      Boxscore
#
#
# Toronto Blue Jays
#  (1)
#  @
#   Cleveland Indians
#  (4)
#      Boxscore
#
#
# Kansas City Royals
#  (4)
#  @
#   Detroit Tigers
#  (5)
#      Boxscore
#
#
#  Washington Nationals
#  (4)
#  @
#   New York Mets
#  (0)
#      Boxscore
#
#
# Boston Red Sox
#  (3)
#  @
#   Oakland Athletics
#  (7)
#      Boxscore
#
#
# Cincinnati Reds
#  (0)
#  @
#   Pittsburgh Pirates
#  (2)
#      Boxscore
#
#     » 2019-04-04 Standings & Scores
#
# Texas Rangers
#  (1)
#  @
#   Los Angeles Angels
#  (3)
#      Boxscore
#
#
# Boston Red Sox
#  (8)
#  @
#   Arizona D'Backs
#  (15)
#      Boxscore
#
#
# Miami Marlins
#  (0)
#  @
#   Atlanta Braves
#  (4)
#      Boxscore
#
#
# Seattle Mariners
#  (8)
#  @
#   Chicago White Sox
#  (10)
#      Boxscore
#
#
# Toronto Blue Jays
#  (2)
#  @
#   Cleveland Indians
#  (3)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (10)
#  @
#   Colorado Rockies
#  (6)
#      Boxscore
#
#
# Oakland Athletics
#  (2)
#  @
#   Houston Astros
#  (3)
#      Boxscore
#
#
# Chicago Cubs
#  (10)
#  @
#   Milwaukee Brewers
#  (13)
#      Boxscore
#
#
# Minnesota Twins
#  (4)
#  @
#   Philadelphia Phillies
#  (10)
#      Boxscore
#
#
# Cincinnati Reds
#  (0)
#  @
#   Pittsburgh Pirates
#  (2)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (5)
#  @
#   San Francisco Giants
#  (2)
#      Boxscore
#
#
#  San Diego Padres
#  (5)
#  @
#   St. Louis Cardinals
#  (3)
#      Boxscore
#
#     » 2019-04-05 Standings & Scores
#
# Texas Rangers
#  (1)
#  @
#   Los Angeles Angels
#  (5)
#      Boxscore
#
#
# Boston Red Sox
#  (4)
#  @
#   Arizona D'Backs
#  (5)
#      Boxscore
#
#
#  Miami Marlins
#  (4)
#  @
#   Atlanta Braves
#  (2)
#      Boxscore
#
#
#  New York Yankees
#  (6)
#  @
#   Baltimore Orioles
#  (4)
#      Boxscore
#
#
#  Seattle Mariners
#  (9)
#  @
#   Chicago White Sox
#  (2)
#      Boxscore
#
#
# Toronto Blue Jays
#  (2)
#  @
#   Cleveland Indians
#  (7)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (7)
#  @
#   Colorado Rockies
#  (2)
#      Boxscore
#
#
# Kansas City Royals
#  (4)
#  @
#   Detroit Tigers
#  (7)
#      Boxscore
#
#
# Oakland Athletics
#  (0)
#  @
#   Houston Astros
#  (6)
#      Boxscore
#
#
#  Chicago Cubs
#  (14)
#  @
#   Milwaukee Brewers
#  (8)
#      Boxscore
#
#
# Washington Nationals
#  (5)
#  @
#   New York Mets
#  (6)
#      Boxscore
#
#
#  Minnesota Twins
#  (6)
#  @
#   Philadelphia Phillies
#  (2)
#      Boxscore
#
#
# Cincinnati Reds
#  (5)
#  @
#   Pittsburgh Pirates
#  (6)
#      Boxscore
#
#
# Tampa Bay Rays
#  (4)
#  @
#   San Francisco Giants
#  (6)
#      Boxscore
#
#
#  San Diego Padres
#  (6)
#  @
#   St. Louis Cardinals
#  (4)
#      Boxscore
#
#     » 2019-04-06 Standings & Scores
#
# Texas Rangers
#  (2)
#  @
#   Los Angeles Angels
#  (7)
#      Boxscore
#
#
#  Boston Red Sox
#  (1)
#  @
#   Arizona D'Backs
#  (0)
#      Boxscore
#
#
# Miami Marlins
#  (3)
#  @
#   Atlanta Braves
#  (4)
#      Boxscore
#
#
#  New York Yankees
#  (15)
#  @
#   Baltimore Orioles
#  (3)
#      Boxscore
#
#
#  Seattle Mariners
#  (12)
#  @
#   Chicago White Sox
#  (5)
#      Boxscore
#
#
# Toronto Blue Jays
#  (1)
#  @
#   Cleveland Indians
#  (3)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (12)
#  @
#   Colorado Rockies
#  (6)
#      Boxscore
#
#
# Kansas City Royals
#  (1)
#  @
#   Detroit Tigers
#  (3)
#      Boxscore
#
#
# Oakland Athletics
#  (8)
#  @
#   Houston Astros
#  (9)
#      Boxscore
#
#
# Chicago Cubs
#  (2)
#  @
#   Milwaukee Brewers
#  (4)
#      Boxscore
#
#
#  Washington Nationals
#  (12)
#  @
#   New York Mets
#  (9)
#      Boxscore
#
#
# Minnesota Twins
#  (1)
#  @
#   Philadelphia Phillies
#  (2)
#      Boxscore
#
#
# Cincinnati Reds
#  (5)
#  @
#   Pittsburgh Pirates
#  (7)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (3)
#  @
#   San Francisco Giants
#  (0)
#      Boxscore
#
#
# San Diego Padres
#  (1)
#  @
#   St. Louis Cardinals
#  (4)
#      Boxscore
#
#     » 2019-04-07 Standings & Scores
#
# Milwaukee Brewers
#  (2)
#  @
#   Los Angeles Angels
#  (5)
#      Boxscore
#
#
# Oakland Athletics
#  (4)
#  @
#   Baltimore Orioles
#  (12)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (5)
#  @
#   Chicago White Sox
#  (1)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (0)
#  @
#   Chicago Cubs
#  (10)
#      Boxscore
#
#
#  Atlanta Braves
#  (8)
#  @
#   Colorado Rockies
#  (6)
#      Boxscore
#
#
# New York Yankees
#  (3)
#  @
#   Houston Astros
#  (4)
#      Boxscore
#
#
#  Seattle Mariners
#  (13)
#  @
#   Kansas City Royals
#  (5)
#      Boxscore
#
#
# Washington Nationals
#  (3)
#  @
#   Philadelphia Phillies
#  (4)
#      Boxscore
#
#
#  San Diego Padres
#  (6)
#  @
#   San Francisco Giants
#  (5)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (3)
#  @
#   St. Louis Cardinals
#  (4)
#      Boxscore
#
#     » 2019-04-08 Standings & Scores
#
# Milwaukee Brewers
#  (8)
#  @
#   Los Angeles Angels
#  (11)
#      Boxscore
#
#
# Texas Rangers
#  (4)
#  @
#   Arizona D'Backs
#  (5)
#      Boxscore
#
#
#  Oakland Athletics
#  (13)
#  @
#   Baltimore Orioles
#  (2)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (7)
#  @
#   Boston Red Sox
#  (5)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (10)
#  @
#   Chicago White Sox
#  (5)
#      Boxscore
#
#
# Miami Marlins
#  (0)
#  @
#   Cincinnati Reds
#  (14)
#      Boxscore
#
#
#  Atlanta Braves
#  (7)
#  @
#   Colorado Rockies
#  (1)
#      Boxscore
#
#
#  Cleveland Indians
#  (8)
#  @
#   Detroit Tigers
#  (2)
#      Boxscore
#
#
# New York Yankees
#  (3)
#  @
#   Houston Astros
#  (6)
#      Boxscore
#
#
#  Seattle Mariners
#  (6)
#  @
#   Kansas City Royals
#  (3)
#      Boxscore
#
#
#  Minnesota Twins
#  (14)
#  @
#   New York Mets
#  (8)
#      Boxscore
#
#
#  Washington Nationals
#  (10)
#  @
#   Philadelphia Phillies
#  (6)
#      Boxscore
#
#
# San Diego Padres
#  (2)
#  @
#   San Francisco Giants
#  (7)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (0)
#  @
#   St. Louis Cardinals
#  (4)
#      Boxscore
#
#     » 2019-04-09 Standings & Scores
#
# Milwaukee Brewers
#  (2)
#  @
#   Los Angeles Angels
#  (4)
#      Boxscore
#
#
#  Texas Rangers
#  (5)
#  @
#   Arizona D'Backs
#  (2)
#      Boxscore
#
#
#  Oakland Athletics
#  (10)
#  @
#   Baltimore Orioles
#  (3)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (9)
#  @
#   Chicago White Sox
#  (1)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (5)
#  @
#   Chicago Cubs
#  (2)
#      Boxscore
#
#
# Miami Marlins
#  (1)
#  @
#   Cincinnati Reds
#  (2)
#      Boxscore
#
#
# Cleveland Indians
#  (1)
#  @
#   Detroit Tigers
#  (4)
#      Boxscore
#
#
# New York Yankees
#  (6)
#  @
#   Houston Astros
#  (8)
#      Boxscore
#
#
#  Seattle Mariners
#  (6)
#  @
#   Kansas City Royals
#  (5)
#      Boxscore
#
#
# Minnesota Twins
#  (6)
#  @
#   New York Mets
#  (9)
#      Boxscore
#
#
#  Washington Nationals
#  (15)
#  @
#   Philadelphia Phillies
#  (1)
#      Boxscore
#
#
#  San Diego Padres
#  (3)
#  @
#   San Francisco Giants
#  (1)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (2)
#  @
#   St. Louis Cardinals
#  (7)
#      Boxscore
#
#     » 2019-04-10 Standings & Scores
#
#  San Diego Padres
#  (7)
#  @
#   Arizona D'Backs
#  (6)
#      Boxscore
#
#
#  New York Mets
#  (6)
#  @
#   Atlanta Braves
#  (3)
#      Boxscore
#
#
#  Oakland Athletics
#  (8)
#  @
#   Baltimore Orioles
#  (5)
#      Boxscore
#
#
# Toronto Blue Jays
#  (6)
#  @
#   Boston Red Sox
#  (7)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (0)
#  @
#   Chicago Cubs
#  (2)
#      Boxscore
#
#
# Miami Marlins
#  (0)
#  @
#   Cincinnati Reds
#  (5)
#      Boxscore
#
#
#  Cleveland Indians
#  (4)
#  @
#   Detroit Tigers
#  (0)
#      Boxscore
#
#
#  Seattle Mariners
#  (7)
#  @
#   Kansas City Royals
#  (6)
#      Boxscore
#
#
# Colorado Rockies
#  (0)
#  @
#   San Francisco Giants
#  (1)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (7)
#  @
#   St. Louis Cardinals
#  (11)
#      Boxscore
#
#     » 2019-04-11 Standings & Scores
#
#  San Diego Padres
#  (2)
#  @
#   Arizona D'Backs
#  (1)
#      Boxscore
#
#
#  New York Mets
#  (6)
#  @
#   Atlanta Braves
#  (2)
#      Boxscore
#
#
# Baltimore Orioles
#  (4)
#  @
#   Boston Red Sox
#  (6)
#      Boxscore
#
#
# Los Angeles Angels
#  (1)
#  @
#   Chicago Cubs
#  (5)
#      Boxscore
#
#
# Cleveland Indians
#  (1)
#  @
#   Kansas City Royals
#  (8)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (8)
#  @
#   Los Angeles Dodgers
#  (5)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (9)
#  @
#   Miami Marlins
#  (1)
#      Boxscore
#
#
#  Chicago White Sox
#  (9)
#  @
#   New York Yankees
#  (6)
#      Boxscore
#
#
#  Houston Astros
#  (10)
#  @
#   Seattle Mariners
#  (6)
#      Boxscore
#
#
# Colorado Rockies
#  (2)
#  @
#   San Francisco Giants
#  (3)
#      Boxscore
#
#
#  Oakland Athletics
#  (8)
#  @
#   Texas Rangers
#  (6)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (11)
#  @
#   Toronto Blue Jays
#  (7)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (6)
#  @
#   Washington Nationals
#  (3)
#      Boxscore
#
#     » 2019-04-12 Standings & Scores
#
#  San Diego Padres
#  (5)
#  @
#   Arizona D'Backs
#  (4)
#      Boxscore
#
#
# New York Mets
#  (7)
#  @
#   Atlanta Braves
#  (11)
#      Boxscore
#
#
#  Baltimore Orioles
#  (9)
#  @
#   Boston Red Sox
#  (5)
#      Boxscore
#
#
#  Los Angeles Angels
#  (6)
#  @
#   Chicago Cubs
#  (5)
#      Boxscore
#
#
# St. Louis Cardinals
#  (2)
#  @
#   Cincinnati Reds
#  (5)
#      Boxscore
#
#
# Cleveland Indians
#  (0)
#  @
#   Kansas City Royals
#  (3)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (4)
#  @
#   Los Angeles Dodgers
#  (1)
#      Boxscore
#
#
# Philadelphia Phillies
#  (3)
#  @
#   Miami Marlins
#  (10)
#      Boxscore
#
#
# Detroit Tigers
#  (3)
#  @
#   Minnesota Twins
#  (4)
#      Boxscore
#
#
# Chicago White Sox
#  (0)
#  @
#   New York Yankees
#  (4)
#      Boxscore
#
#
#  Houston Astros
#  (3)
#  @
#   Seattle Mariners
#  (1)
#      Boxscore
#
#
# Colorado Rockies
#  (2)
#  @
#   San Francisco Giants
#  (5)
#      Boxscore
#
#
# Tampa Bay Rays
#  (1)
#  @
#   Toronto Blue Jays
#  (3)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (2)
#  @
#   Washington Nationals
#  (3)
#      Boxscore
#
#     » 2019-04-13 Standings & Scores
#
# San Diego Padres
#  (4)
#  @
#   Arizona D'Backs
#  (8)
#      Boxscore
#
#
# New York Mets
#  (3)
#  @
#   Atlanta Braves
#  (7)
#      Boxscore
#
#
# Baltimore Orioles
#  (0)
#  @
#   Boston Red Sox
#  (4)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (9)
#  @
#   Cincinnati Reds
#  (5)
#      Boxscore
#
#
# Cleveland Indians
#  (8)
#  @
#   Kansas City Royals
#  (9)
#      Boxscore
#
#
# Milwaukee Brewers
#  (1)
#  @
#   Los Angeles Dodgers
#  (7)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (3)
#  @
#   Miami Marlins
#  (1)
#      Boxscore
#
#
# Detroit Tigers
#  (4)
#  @
#   Minnesota Twins
#  (6)
#      Boxscore
#
#
#  Chicago White Sox
#  (5)
#  @
#   New York Yankees
#  (2)
#      Boxscore
#
#
#  Houston Astros
#  (3)
#  @
#   Seattle Mariners
#  (2)
#      Boxscore
#
#
#  Colorado Rockies
#  (4)
#  @
#   San Francisco Giants
#  (0)
#      Boxscore
#
#
# Oakland Athletics
#  (7)
#  @
#   Texas Rangers
#  (8)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (8)
#  @
#   Toronto Blue Jays
#  (4)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (4)
#  @
#   Washington Nationals
#  (3)
#      Boxscore
#
#     » 2019-04-14 Standings & Scores
#
#  Baltimore Orioles
#  (8)
#  @
#   Boston Red Sox
#  (1)
#      Boxscore
#
#
# Kansas City Royals
#  (4)
#  @
#   Chicago White Sox
#  (5)
#      Boxscore
#
#
# Cincinnati Reds
#  (3)
#  @
#   Los Angeles Dodgers
#  (4)
#      Boxscore
#
#
#  Chicago Cubs
#  (7)
#  @
#   Miami Marlins
#  (2)
#      Boxscore
#
#
# St. Louis Cardinals
#  (7)
#  @
#   Milwaukee Brewers
#  (10)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (5)
#  @
#   Minnesota Twins
#  (3)
#      Boxscore
#
#
#  New York Mets
#  (7)
#  @
#   Philadelphia Phillies
#  (6)
#      Boxscore
#
#
#  Colorado Rockies
#  (5)
#  @
#   San Diego Padres
#  (2)
#      Boxscore
#
#
#  Cleveland Indians
#  (6)
#  @
#   Seattle Mariners
#  (4)
#      Boxscore
#
#
# Los Angeles Angels
#  (7)
#  @
#   Texas Rangers
#  (12)
#      Boxscore
#
#     » 2019-04-15 Standings & Scores
#
#  Arizona D'Backs
#  (9)
#  @
#   Atlanta Braves
#  (6)
#      Boxscore
#
#
# Kansas City Royals
#  (1)
#  @
#   Chicago White Sox
#  (5)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (5)
#  @
#   Detroit Tigers
#  (3)
#      Boxscore
#
#
# Cincinnati Reds
#  (1)
#  @
#   Los Angeles Dodgers
#  (6)
#      Boxscore
#
#
#  Chicago Cubs
#  (4)
#  @
#   Miami Marlins
#  (0)
#      Boxscore
#
#
# St. Louis Cardinals
#  (4)
#  @
#   Milwaukee Brewers
#  (8)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (6)
#  @
#   Minnesota Twins
#  (5)
#      Boxscore
#
#
# Boston Red Sox
#  (0)
#  @
#   New York Yankees
#  (8)
#      Boxscore
#
#
#  Houston Astros
#  (9)
#  @
#   Oakland Athletics
#  (1)
#      Boxscore
#
#
# New York Mets
#  (3)
#  @
#   Philadelphia Phillies
#  (14)
#      Boxscore
#
#
#  Colorado Rockies
#  (8)
#  @
#   San Diego Padres
#  (2)
#      Boxscore
#
#
#  Cleveland Indians
#  (4)
#  @
#   Seattle Mariners
#  (2)
#      Boxscore
#
#
# Baltimore Orioles
#  (2)
#  @
#   Tampa Bay Rays
#  (4)
#      Boxscore
#
#
# Los Angeles Angels
#  (0)
#  @
#   Texas Rangers
#  (5)
#      Boxscore
#
#
#  San Francisco Giants
#  (7)
#  @
#   Washington Nationals
#  (3)
#      Boxscore
#
#     » 2019-04-16 Standings & Scores
#
#  Arizona D'Backs
#  (3)
#  @
#   Atlanta Braves
#  (2)
#      Boxscore
#
#
#  Kansas City Royals
#  (4)
#  @
#   Chicago White Sox
#  (3)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (3)
#  @
#   Detroit Tigers
#  (2)
#      Boxscore
#
#
# Cincinnati Reds
#  (2)
#  @
#   Los Angeles Dodgers
#  (3)
#      Boxscore
#
#
#  Chicago Cubs
#  (6)
#  @
#   Miami Marlins
#  (0)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (6)
#  @
#   Milwaukee Brewers
#  (3)
#      Boxscore
#
#
# Toronto Blue Jays
#  (1)
#  @
#   Minnesota Twins
#  (4)
#      Boxscore
#
#
# Boston Red Sox
#  (3)
#  @
#   New York Yankees
#  (5)
#      Boxscore
#
#
# Houston Astros
#  (1)
#  @
#   Oakland Athletics
#  (2)
#      Boxscore
#
#
# New York Mets
#  (2)
#  @
#   Philadelphia Phillies
#  (3)
#      Boxscore
#
#
#  Cleveland Indians
#  (1)
#  @
#   Seattle Mariners
#  (0)
#      Boxscore
#
#
# Baltimore Orioles
#  (1)
#  @
#   Tampa Bay Rays
#  (8)
#      Boxscore
#
#
# Los Angeles Angels
#  (4)
#  @
#   Texas Rangers
#  (5)
#      Boxscore
#
#
# San Francisco Giants
#  (6)
#  @
#   Washington Nationals
#  (9)
#      Boxscore
#
#     » 2019-04-17 Standings & Scores
#
#  Seattle Mariners
#  (11)
#  @
#   Los Angeles Angels
#  (10)
#      Boxscore
#
#
#  Arizona D'Backs
#  (4)
#  @
#   Atlanta Braves
#  (1)
#      Boxscore
#
#
# Philadelphia Phillies
#  (2)
#  @
#   Colorado Rockies
#  (6)
#      Boxscore
#
#
# Chicago White Sox
#  (7)
#  @
#   Detroit Tigers
#  (9)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (3)
#  @
#   Milwaukee Brewers
#  (1)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (7)
#  @
#   Minnesota Twins
#  (4)
#      Boxscore
#
#
#  Kansas City Royals
#  (6)
#  @
#   New York Yankees
#  (1)
#      Boxscore
#
#
#  Cincinnati Reds
#  (4)
#  @
#   San Diego Padres
#  (1)
#      Boxscore
#
#
#  Baltimore Orioles
#  (6)
#  @
#   Tampa Bay Rays
#  (5)
#      Boxscore
#
#
# San Francisco Giants
#  (2)
#  @
#   Washington Nationals
#  (4)
#      Boxscore
#
#     » 2019-04-18 Standings & Scores
#
#  Seattle Mariners
#  (5)
#  @
#   Los Angeles Angels
#  (3)
#      Boxscore
#
#
# Arizona D'Backs
#  (1)
#  @
#   Chicago Cubs
#  (5)
#      Boxscore
#
#
# Philadelphia Phillies
#  (3)
#  @
#   Colorado Rockies
#  (4)
#      Boxscore
#
#
#  Chicago White Sox
#  (7)
#  @
#   Detroit Tigers
#  (3)
#      Boxscore
#
#
# Washington Nationals
#  (2)
#  @
#   Miami Marlins
#  (3)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (5)
#  @
#   Milwaukee Brewers
#  (3)
#      Boxscore
#
#
# Kansas City Royals
#  (2)
#  @
#   New York Yankees
#  (6)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (5)
#  @
#   Oakland Athletics
#  (1)
#      Boxscore
#
#
# San Francisco Giants
#  (1)
#  @
#   Pittsburgh Pirates
#  (4)
#      Boxscore
#
#
#  Cincinnati Reds
#  (3)
#  @
#   San Diego Padres
#  (2)
#      Boxscore
#
#
#  New York Mets
#  (5)
#  @
#   St. Louis Cardinals
#  (4)
#      Boxscore
#
#
#  Boston Red Sox
#  (6)
#  @
#   Tampa Bay Rays
#  (4)
#      Boxscore
#
#
#  Houston Astros
#  (7)
#  @
#   Texas Rangers
#  (2)
#      Boxscore
#
#     » 2019-04-19 Standings & Scores
#
#  Seattle Mariners
#  (6)
#  @
#   Los Angeles Angels
#  (5)
#      Boxscore
#
#
#  Minnesota Twins
#  (6)
#  @
#   Baltimore Orioles
#  (5)
#      Boxscore
#
#
#  Minnesota Twins
#  (16)
#  @
#   Baltimore Orioles
#  (7)
#      Boxscore
#
#
#  Arizona D'Backs
#  (6)
#  @
#   Chicago Cubs
#  (0)
#      Boxscore
#
#
# Atlanta Braves
#  (4)
#  @
#   Cleveland Indians
#  (8)
#      Boxscore
#
#
#  Atlanta Braves
#  (8)
#  @
#   Cleveland Indians
#  (7)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (8)
#  @
#   Colorado Rockies
#  (5)
#      Boxscore
#
#
# Washington Nationals
#  (3)
#  @
#   Miami Marlins
#  (9)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (0)
#  @
#   Milwaukee Brewers
#  (5)
#      Boxscore
#
#
# Kansas City Royals
#  (2)
#  @
#   New York Yankees
#  (9)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (10)
#  @
#   Oakland Athletics
#  (1)
#      Boxscore
#
#
# San Francisco Giants
#  (1)
#  @
#   Pittsburgh Pirates
#  (3)
#      Boxscore
#
#
#  Cincinnati Reds
#  (4)
#  @
#   San Diego Padres
#  (2)
#      Boxscore
#
#
# New York Mets
#  (2)
#  @
#   St. Louis Cardinals
#  (10)
#      Boxscore
#
#
#  Boston Red Sox
#  (6)
#  @
#   Tampa Bay Rays
#  (5)
#      Boxscore
#
#
# Houston Astros
#  (4)
#  @
#   Texas Rangers
#  (9)
#      Boxscore
#
#     » 2019-04-20 Standings & Scores
#
# Seattle Mariners
#  (6)
#  @
#   Los Angeles Angels
#  (8)
#      Boxscore
#
#
#  Minnesota Twins
#  (4)
#  @
#   Baltimore Orioles
#  (3)
#      Boxscore
#
#
# Arizona D'Backs
#  (1)
#  @
#   Chicago Cubs
#  (2)
#      Boxscore
#
#
#  Atlanta Braves
#  (11)
#  @
#   Cleveland Indians
#  (5)
#      Boxscore
#
#
# Philadelphia Phillies
#  (1)
#  @
#   Colorado Rockies
#  (4)
#      Boxscore
#
#
# Chicago White Sox
#  (3)
#  @
#   Detroit Tigers
#  (4)
#      Boxscore
#
#
#  Washington Nationals
#  (5)
#  @
#   Miami Marlins
#  (0)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (6)
#  @
#   Milwaukee Brewers
#  (5)
#      Boxscore
#
#
# Kansas City Royals
#  (6)
#  @
#   New York Yankees
#  (7)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (5)
#  @
#   Oakland Athletics
#  (4)
#      Boxscore
#
#
#  San Francisco Giants
#  (3)
#  @
#   Pittsburgh Pirates
#  (2)
#      Boxscore
#
#
# Cincinnati Reds
#  (3)
#  @
#   San Diego Padres
#  (4)
#      Boxscore
#
#
# New York Mets
#  (4)
#  @
#   St. Louis Cardinals
#  (6)
#      Boxscore
#
#
#  Boston Red Sox
#  (4)
#  @
#   Tampa Bay Rays
#  (3)
#      Boxscore
#
#
# Houston Astros
#  (10)
#  @
#   Texas Rangers
#  (11)
#      Boxscore
#
#     » 2019-04-21 Standings & Scores
#
#  New York Yankees
#  (4)
#  @
#   Los Angeles Angels
#  (3)
#      Boxscore
#
#
#  Chicago White Sox
#  (12)
#  @
#   Baltimore Orioles
#  (2)
#      Boxscore
#
#
# Washington Nationals
#  (5)
#  @
#   Colorado Rockies
#  (7)
#      Boxscore
#
#
#  Minnesota Twins
#  (9)
#  @
#   Houston Astros
#  (5)
#      Boxscore
#
#
# Philadelphia Phillies
#  (1)
#  @
#   New York Mets
#  (5)
#      Boxscore
#
#
# Texas Rangers
#  (1)
#  @
#   Oakland Athletics
#  (6)
#      Boxscore
#
#
#  Arizona D'Backs
#  (12)
#  @
#   Pittsburgh Pirates
#  (4)
#      Boxscore
#
#
# Milwaukee Brewers
#  (5)
#  @
#   St. Louis Cardinals
#  (13)
#      Boxscore
#
#
# Kansas City Royals
#  (3)
#  @
#   Tampa Bay Rays
#  (6)
#      Boxscore
#
#     » 2019-04-22 Standings & Scores
#
#  New York Yankees
#  (7)
#  @
#   Los Angeles Angels
#  (5)
#      Boxscore
#
#
# Chicago White Sox
#  (1)
#  @
#   Baltimore Orioles
#  (9)
#      Boxscore
#
#
#  Detroit Tigers
#  (7)
#  @
#   Boston Red Sox
#  (4)
#      Boxscore
#
#
#  Detroit Tigers
#  (4)
#  @
#   Boston Red Sox
#  (2)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (2)
#  @
#   Chicago Cubs
#  (7)
#      Boxscore
#
#
# Atlanta Braves
#  (6)
#  @
#   Cincinnati Reds
#  (7)
#      Boxscore
#
#
#  Miami Marlins
#  (3)
#  @
#   Cleveland Indians
#  (1)
#      Boxscore
#
#
#  Washington Nationals
#  (6)
#  @
#   Colorado Rockies
#  (3)
#      Boxscore
#
#
# Minnesota Twins
#  (4)
#  @
#   Houston Astros
#  (10)
#      Boxscore
#
#
# Philadelphia Phillies
#  (0)
#  @
#   New York Mets
#  (9)
#      Boxscore
#
#
# Texas Rangers
#  (5)
#  @
#   Oakland Athletics
#  (11)
#      Boxscore
#
#
#  Arizona D'Backs
#  (2)
#  @
#   Pittsburgh Pirates
#  (1)
#      Boxscore
#
#
# Seattle Mariners
#  (3)
#  @
#   San Diego Padres
#  (6)
#      Boxscore
#
#
# Milwaukee Brewers
#  (3)
#  @
#   St. Louis Cardinals
#  (4)
#      Boxscore
#
#
# Kansas City Royals
#  (2)
#  @
#   Tampa Bay Rays
#  (5)
#      Boxscore
#
#
#  San Francisco Giants
#  (7)
#  @
#   Toronto Blue Jays
#  (6)
#      Boxscore
#
#     » 2019-04-23 Standings & Scores
#
#  New York Yankees
#  (6)
#  @
#   Los Angeles Angels
#  (5)
#      Boxscore
#
#
# Chicago White Sox
#  (3)
#  @
#   Baltimore Orioles
#  (4)
#      Boxscore
#
#
# Detroit Tigers
#  (4)
#  @
#   Boston Red Sox
#  (11)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (6)
#  @
#   Chicago Cubs
#  (7)
#      Boxscore
#
#
#  Atlanta Braves
#  (3)
#  @
#   Cincinnati Reds
#  (1)
#      Boxscore
#
#
# Miami Marlins
#  (2)
#  @
#   Cleveland Indians
#  (6)
#      Boxscore
#
#
# Washington Nationals
#  (5)
#  @
#   Colorado Rockies
#  (9)
#      Boxscore
#
#
# Minnesota Twins
#  (1)
#  @
#   Houston Astros
#  (7)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (6)
#  @
#   New York Mets
#  (0)
#      Boxscore
#
#
# Texas Rangers
#  (5)
#  @
#   Oakland Athletics
#  (6)
#      Boxscore
#
#
#  Arizona D'Backs
#  (11)
#  @
#   Pittsburgh Pirates
#  (2)
#      Boxscore
#
#
# Seattle Mariners
#  (0)
#  @
#   San Diego Padres
#  (1)
#      Boxscore
#
#
# Milwaukee Brewers
#  (2)
#  @
#   St. Louis Cardinals
#  (5)
#      Boxscore
#
#
#  Kansas City Royals
#  (10)
#  @
#   Tampa Bay Rays
#  (2)
#      Boxscore
#
#
#  San Francisco Giants
#  (4)
#  @
#   Toronto Blue Jays
#  (0)
#      Boxscore
#
#     » 2019-04-24 Standings & Scores
#
# New York Yankees
#  (5)
#  @
#   Los Angeles Angels
#  (11)
#      Boxscore
#
#
# Detroit Tigers
#  (3)
#  @
#   Boston Red Sox
#  (7)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (2)
#  @
#   Chicago Cubs
#  (1)
#      Boxscore
#
#
# Atlanta Braves
#  (2)
#  @
#   Cincinnati Reds
#  (4)
#      Boxscore
#
#
#  Cleveland Indians
#  (2)
#  @
#   Houston Astros
#  (1)
#      Boxscore
#
#
#  Miami Marlins
#  (3)
#  @
#   Philadelphia Phillies
#  (1)
#      Boxscore
#
#
#  Arizona D'Backs
#  (5)
#  @
#   Pittsburgh Pirates
#  (0)
#      Boxscore
#
#
# Texas Rangers
#  (2)
#  @
#   Seattle Mariners
#  (14)
#      Boxscore
#
#     » 2019-04-25 Standings & Scores
#
# Chicago Cubs
#  (3)
#  @
#   Arizona D'Backs
#  (8)
#      Boxscore
#
#
#  Colorado Rockies
#  (8)
#  @
#   Atlanta Braves
#  (4)
#      Boxscore
#
#
# Detroit Tigers
#  (11)
#  @
#   Chicago White Sox
#  (12)
#      Boxscore
#
#
#  Cleveland Indians
#  (6)
#  @
#   Houston Astros
#  (3)
#      Boxscore
#
#
#  Los Angeles Angels
#  (5)
#  @
#   Kansas City Royals
#  (1)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (2)
#  @
#   Los Angeles Dodgers
#  (6)
#      Boxscore
#
#
# Baltimore Orioles
#  (1)
#  @
#   Minnesota Twins
#  (6)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (10)
#  @
#   New York Mets
#  (2)
#      Boxscore
#
#
# Miami Marlins
#  (0)
#  @
#   Philadelphia Phillies
#  (4)
#      Boxscore
#
#
# Texas Rangers
#  (4)
#  @
#   Seattle Mariners
#  (5)
#      Boxscore
#
#
#  New York Yankees
#  (7)
#  @
#   San Francisco Giants
#  (3)
#      Boxscore
#
#
#  Cincinnati Reds
#  (12)
#  @
#   St. Louis Cardinals
#  (1)
#      Boxscore
#
#
# Oakland Athletics
#  (2)
#  @
#   Toronto Blue Jays
#  (4)
#      Boxscore
#
#
#  San Diego Padres
#  (4)
#  @
#   Washington Nationals
#  (3)
#      Boxscore
#
#     » 2019-04-26 Standings & Scores
#
#  Chicago Cubs
#  (9)
#  @
#   Arizona D'Backs
#  (1)
#      Boxscore
#
#
#  Colorado Rockies
#  (9)
#  @
#   Atlanta Braves
#  (5)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (2)
#  @
#   Boston Red Sox
#  (1)
#      Boxscore
#
#
# Cleveland Indians
#  (3)
#  @
#   Houston Astros
#  (4)
#      Boxscore
#
#
# Los Angeles Angels
#  (4)
#  @
#   Kansas City Royals
#  (9)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (1)
#  @
#   Los Angeles Dodgers
#  (3)
#      Boxscore
#
#
# Baltimore Orioles
#  (2)
#  @
#   Minnesota Twins
#  (9)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (8)
#  @
#   New York Mets
#  (6)
#      Boxscore
#
#
# Miami Marlins
#  (9)
#  @
#   Philadelphia Phillies
#  (12)
#      Boxscore
#
#
#  Texas Rangers
#  (15)
#  @
#   Seattle Mariners
#  (1)
#      Boxscore
#
#
#  New York Yankees
#  (6)
#  @
#   San Francisco Giants
#  (4)
#      Boxscore
#
#
# Cincinnati Reds
#  (3)
#  @
#   St. Louis Cardinals
#  (6)
#      Boxscore
#
#
# Oakland Athletics
#  (1)
#  @
#   Toronto Blue Jays
#  (7)
#      Boxscore
#
#
#  San Diego Padres
#  (8)
#  @
#   Washington Nationals
#  (3)
#      Boxscore
#
#     » 2019-04-27 Standings & Scores
#
#  Chicago Cubs
#  (6)
#  @
#   Arizona D'Backs
#  (5)
#      Boxscore
#
#
# Colorado Rockies
#  (7)
#  @
#   Atlanta Braves
#  (8)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (5)
#  @
#   Boston Red Sox
#  (2)
#      Boxscore
#
#
# Detroit Tigers
#  (1)
#  @
#   Chicago White Sox
#  (4)
#      Boxscore
#
#
# Cleveland Indians
#  (1)
#  @
#   Houston Astros
#  (4)
#      Boxscore
#
#
#  Los Angeles Angels
#  (7)
#  @
#   Kansas City Royals
#  (3)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (6)
#  @
#   Los Angeles Dodgers
#  (7)
#      Boxscore
#
#
# Baltimore Orioles
#  (1)
#  @
#   Minnesota Twins
#  (4)
#      Boxscore
#
#
# Milwaukee Brewers
#  (2)
#  @
#   New York Mets
#  (5)
#      Boxscore
#
#
# Miami Marlins
#  (1)
#  @
#   Philadelphia Phillies
#  (5)
#      Boxscore
#
#
#  Texas Rangers
#  (14)
#  @
#   Seattle Mariners
#  (1)
#      Boxscore
#
#
#  New York Yankees
#  (11)
#  @
#   San Francisco Giants
#  (5)
#      Boxscore
#
#
# Cincinnati Reds
#  (2)
#  @
#   St. Louis Cardinals
#  (5)
#      Boxscore
#
#
# Oakland Athletics
#  (4)
#  @
#   Toronto Blue Jays
#  (5)
#      Boxscore
#
#
# San Diego Padres
#  (6)
#  @
#   Washington Nationals
#  (7)
#      Boxscore
#
#     » 2019-04-28 Standings & Scores
#
# San Diego Padres
#  (1)
#  @
#   Atlanta Braves
#  (3)
#      Boxscore
#
#
# Oakland Athletics
#  (4)
#  @
#   Boston Red Sox
#  (9)
#      Boxscore
#
#
# Baltimore Orioles
#  (3)
#  @
#   Chicago White Sox
#  (5)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (8)
#  @
#   Kansas City Royals
#  (5)
#      Boxscore
#
#
# Colorado Rockies
#  (1)
#  @
#   Milwaukee Brewers
#  (5)
#      Boxscore
#
#
# Houston Astros
#  (0)
#  @
#   Minnesota Twins
#  (1)
#      Boxscore
#
#
#  Cincinnati Reds
#  (5)
#  @
#   New York Mets
#  (4)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (2)
#  @
#   San Francisco Giants
#  (3)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (6)
#  @
#   Washington Nationals
#  (3)
#      Boxscore
#
#     » 2019-04-29 Standings & Scores
#
# Toronto Blue Jays
#  (3)
#  @
#   Los Angeles Angels
#  (4)
#      Boxscore
#
#
# New York Yankees
#  (1)
#  @
#   Arizona D'Backs
#  (3)
#      Boxscore
#
#
#  San Diego Padres
#  (4)
#  @
#   Atlanta Braves
#  (3)
#      Boxscore
#
#
# Oakland Athletics
#  (1)
#  @
#   Boston Red Sox
#  (5)
#      Boxscore
#
#
#  Cleveland Indians
#  (7)
#  @
#   Miami Marlins
#  (4)
#      Boxscore
#
#
# Colorado Rockies
#  (3)
#  @
#   Milwaukee Brewers
#  (4)
#      Boxscore
#
#
#  Houston Astros
#  (11)
#  @
#   Minnesota Twins
#  (0)
#      Boxscore
#
#
# Cincinnati Reds
#  (3)
#  @
#   New York Mets
#  (4)
#      Boxscore
#
#
#  Detroit Tigers
#  (3)
#  @
#   Philadelphia Phillies
#  (1)
#      Boxscore
#
#
#  Chicago Cubs
#  (6)
#  @
#   Seattle Mariners
#  (5)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (10)
#  @
#   San Francisco Giants
#  (3)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (6)
#  @
#   Texas Rangers
#  (4)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (3)
#  @
#   Washington Nationals
#  (2)
#      Boxscore
#
#     » 2019-04-30 Standings & Scores
#
# Toronto Blue Jays
#  (3)
#  @
#   Los Angeles Angels
#  (6)
#      Boxscore
#
#
# New York Yankees
#  (2)
#  @
#   Arizona D'Backs
#  (3)
#      Boxscore
#
#
# San Diego Padres
#  (1)
#  @
#   Atlanta Braves
#  (5)
#      Boxscore
#
#
# Oakland Athletics
#  (3)
#  @
#   Boston Red Sox
#  (7)
#      Boxscore
#
#
#  Baltimore Orioles
#  (5)
#  @
#   Chicago White Sox
#  (4)
#      Boxscore
#
#
# Baltimore Orioles
#  (6)
#  @
#   Chicago White Sox
#  (7)
#      Boxscore
#
#
# Tampa Bay Rays
#  (2)
#  @
#   Kansas City Royals
#  (3)
#      Boxscore
#
#
# Tampa Bay Rays
#  (2)
#  @
#   Kansas City Royals
#  (8)
#      Boxscore
#
#
# Cleveland Indians
#  (2)
#  @
#   Miami Marlins
#  (4)
#      Boxscore
#
#
#  Colorado Rockies
#  (11)
#  @
#   Milwaukee Brewers
#  (4)
#      Boxscore
#
#
# Houston Astros
#  (2)
#  @
#   Minnesota Twins
#  (6)
#      Boxscore
#
#
#  Cincinnati Reds
#  (1)
#  @
#   New York Mets
#  (0)
#      Boxscore
#
#
# Detroit Tigers
#  (3)
#  @
#   Philadelphia Phillies
#  (7)
#      Boxscore
#
#
#  Chicago Cubs
#  (11)
#  @
#   Seattle Mariners
#  (0)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (1)
#  @
#   San Francisco Giants
#  (2)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (7)
#  @
#   Texas Rangers
#  (5)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (5)
#  @
#   Washington Nationals
#  (1)
#      Boxscore
#
#     » 2019-05-01 Standings & Scores
#
# Toronto Blue Jays
#  (2)
#  @
#   Los Angeles Angels
#  (6)
#      Boxscore
#
#
#  San Diego Padres
#  (11)
#  @
#   Atlanta Braves
#  (2)
#      Boxscore
#
#
# Boston Red Sox
#  (4)
#  @
#   Chicago White Sox
#  (6)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (3)
#  @
#   Kansas City Royals
#  (1)
#      Boxscore
#
#
#  Colorado Rockies
#  (11)
#  @
#   Milwaukee Brewers
#  (6)
#      Boxscore
#
#
# Houston Astros
#  (2)
#  @
#   Minnesota Twins
#  (8)
#      Boxscore
#
#
# Cincinnati Reds
#  (0)
#  @
#   New York Mets
#  (1)
#      Boxscore
#
#
# St. Louis Cardinals
#  (1)
#  @
#   Washington Nationals
#  (2)
#      Boxscore
#
#     » 2019-05-02 Standings & Scores
#
#  Tampa Bay Rays
#  (7)
#  @
#   Baltimore Orioles
#  (0)
#      Boxscore
#
#
#  Boston Red Sox
#  (6)
#  @
#   Chicago White Sox
#  (1)
#      Boxscore
#
#
# St. Louis Cardinals
#  (0)
#  @
#   Chicago Cubs
#  (4)
#      Boxscore
#
#
#  San Francisco Giants
#  (12)
#  @
#   Cincinnati Reds
#  (11)
#      Boxscore
#
#
# Seattle Mariners
#  (1)
#  @
#   Cleveland Indians
#  (2)
#      Boxscore
#
#
#  Arizona D'Backs
#  (10)
#  @
#   Colorado Rockies
#  (9)
#      Boxscore
#
#
# Kansas City Royals
#  (3)
#  @
#   Detroit Tigers
#  (4)
#      Boxscore
#
#
#  Atlanta Braves
#  (7)
#  @
#   Miami Marlins
#  (2)
#      Boxscore
#
#
# New York Mets
#  (1)
#  @
#   Milwaukee Brewers
#  (3)
#      Boxscore
#
#
# Minnesota Twins
#  (3)
#  @
#   New York Yankees
#  (6)
#      Boxscore
#
#
# Washington Nationals
#  (2)
#  @
#   Philadelphia Phillies
#  (4)
#      Boxscore
#
#
#  Oakland Athletics
#  (14)
#  @
#   Pittsburgh Pirates
#  (1)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (4)
#  @
#   San Diego Padres
#  (3)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (1)
#  @
#   Texas Rangers
#  (0)
#      Boxscore
#
#     » 2019-05-03 Standings & Scores
#
#  Houston Astros
#  (14)
#  @
#   Los Angeles Angels
#  (2)
#      Boxscore
#
#
# Tampa Bay Rays
#  (0)
#  @
#   Baltimore Orioles
#  (3)
#      Boxscore
#
#
#  Boston Red Sox
#  (15)
#  @
#   Chicago White Sox
#  (2)
#      Boxscore
#
#
# St. Louis Cardinals
#  (5)
#  @
#   Chicago Cubs
#  (6)
#      Boxscore
#
#
# San Francisco Giants
#  (2)
#  @
#   Cincinnati Reds
#  (9)
#      Boxscore
#
#
# Seattle Mariners
#  (4)
#  @
#   Cleveland Indians
#  (5)
#      Boxscore
#
#
#  Arizona D'Backs
#  (9)
#  @
#   Colorado Rockies
#  (2)
#      Boxscore
#
#
#  Kansas City Royals
#  (15)
#  @
#   Detroit Tigers
#  (3)
#      Boxscore
#
#
#  Atlanta Braves
#  (9)
#  @
#   Miami Marlins
#  (2)
#      Boxscore
#
#
# New York Mets
#  (3)
#  @
#   Milwaukee Brewers
#  (4)
#      Boxscore
#
#
#  Minnesota Twins
#  (7)
#  @
#   New York Yankees
#  (3)
#      Boxscore
#
#
#  Washington Nationals
#  (10)
#  @
#   Philadelphia Phillies
#  (8)
#      Boxscore
#
#
# Oakland Athletics
#  (4)
#  @
#   Pittsburgh Pirates
#  (6)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (7)
#  @
#   San Diego Padres
#  (6)
#      Boxscore
#
#
# Toronto Blue Jays
#  (5)
#  @
#   Texas Rangers
#  (8)
#      Boxscore
#
#     » 2019-05-04 Standings & Scores
#
#  Houston Astros
#  (10)
#  @
#   Los Angeles Angels
#  (4)
#      Boxscore
#
#
#  Boston Red Sox
#  (9)
#  @
#   Chicago White Sox
#  (2)
#      Boxscore
#
#
# St. Louis Cardinals
#  (5)
#  @
#   Chicago Cubs
#  (13)
#      Boxscore
#
#
#  San Francisco Giants
#  (6)
#  @
#   Cincinnati Reds
#  (5)
#      Boxscore
#
#
#  Seattle Mariners
#  (10)
#  @
#   Cleveland Indians
#  (0)
#      Boxscore
#
#
# Arizona D'Backs
#  (7)
#  @
#   Colorado Rockies
#  (8)
#      Boxscore
#
#
# Kansas City Royals
#  (2)
#  @
#   Detroit Tigers
#  (5)
#      Boxscore
#
#
#  Atlanta Braves
#  (3)
#  @
#   Miami Marlins
#  (1)
#      Boxscore
#
#
# New York Mets
#  (2)
#  @
#   Milwaukee Brewers
#  (3)
#      Boxscore
#
#
# Minnesota Twins
#  (1)
#  @
#   New York Yankees
#  (4)
#      Boxscore
#
#
# Washington Nationals
#  (1)
#  @
#   Philadelphia Phillies
#  (7)
#      Boxscore
#
#
# Oakland Athletics
#  (3)
#  @
#   Pittsburgh Pirates
#  (5)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (5)
#  @
#   San Diego Padres
#  (8)
#      Boxscore
#
#
# Toronto Blue Jays
#  (2)
#  @
#   Texas Rangers
#  (10)
#      Boxscore
#
#     » 2019-05-05 Standings & Scores
#
# Boston Red Sox
#  (1)
#  @
#   Baltimore Orioles
#  (4)
#      Boxscore
#
#
#  Miami Marlins
#  (6)
#  @
#   Chicago Cubs
#  (5)
#      Boxscore
#
#
# San Francisco Giants
#  (4)
#  @
#   Cincinnati Reds
#  (12)
#      Boxscore
#
#
#  Chicago White Sox
#  (9)
#  @
#   Cleveland Indians
#  (1)
#      Boxscore
#
#
# Kansas City Royals
#  (4)
#  @
#   Houston Astros
#  (6)
#      Boxscore
#
#
# Atlanta Braves
#  (3)
#  @
#   Los Angeles Dodgers
#  (5)
#      Boxscore
#
#
# Washington Nationals
#  (3)
#  @
#   Milwaukee Brewers
#  (5)
#      Boxscore
#
#
# Seattle Mariners
#  (3)
#  @
#   New York Yankees
#  (7)
#      Boxscore
#
#
# New York Mets
#  (0)
#  @
#   San Diego Padres
#  (4)
#      Boxscore
#
#
# Philadelphia Phillies
#  (0)
#  @
#   St. Louis Cardinals
#  (6)
#      Boxscore
#
#
# Arizona D'Backs
#  (1)
#  @
#   Tampa Bay Rays
#  (12)
#      Boxscore
#
#
#  Minnesota Twins
#  (8)
#  @
#   Toronto Blue Jays
#  (0)
#      Boxscore
#
#     » 2019-05-06 Standings & Scores
#
#  Boston Red Sox
#  (8)
#  @
#   Baltimore Orioles
#  (5)
#      Boxscore
#
#
# Miami Marlins
#  (2)
#  @
#   Chicago Cubs
#  (5)
#      Boxscore
#
#
#  Chicago White Sox
#  (2)
#  @
#   Cleveland Indians
#  (0)
#      Boxscore
#
#
#  San Francisco Giants
#  (14)
#  @
#   Colorado Rockies
#  (4)
#      Boxscore
#
#
#  Los Angeles Angels
#  (5)
#  @
#   Detroit Tigers
#  (2)
#      Boxscore
#
#
#  Kansas City Royals
#  (12)
#  @
#   Houston Astros
#  (2)
#      Boxscore
#
#
# Atlanta Braves
#  (0)
#  @
#   Los Angeles Dodgers
#  (9)
#      Boxscore
#
#
# Washington Nationals
#  (0)
#  @
#   Milwaukee Brewers
#  (6)
#      Boxscore
#
#
# Seattle Mariners
#  (4)
#  @
#   New York Yankees
#  (5)
#      Boxscore
#
#
# Cincinnati Reds
#  (0)
#  @
#   Oakland Athletics
#  (2)
#      Boxscore
#
#
# Texas Rangers
#  (4)
#  @
#   Pittsburgh Pirates
#  (5)
#      Boxscore
#
#
#  New York Mets
#  (7)
#  @
#   San Diego Padres
#  (6)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (11)
#  @
#   St. Louis Cardinals
#  (1)
#      Boxscore
#
#
# Arizona D'Backs
#  (3)
#  @
#   Tampa Bay Rays
#  (6)
#      Boxscore
#
#
#  Minnesota Twins
#  (3)
#  @
#   Toronto Blue Jays
#  (0)
#      Boxscore
#
#     » 2019-05-07 Standings & Scores
#
#  Boston Red Sox
#  (2)
#  @
#   Baltimore Orioles
#  (1)
#      Boxscore
#
#
# Miami Marlins
#  (2)
#  @
#   Chicago Cubs
#  (3)
#      Boxscore
#
#
# Chicago White Sox
#  (3)
#  @
#   Cleveland Indians
#  (5)
#      Boxscore
#
#
# Los Angeles Angels
#  (3)
#  @
#   Detroit Tigers
#  (10)
#      Boxscore
#
#
# Kansas City Royals
#  (0)
#  @
#   Houston Astros
#  (9)
#      Boxscore
#
#
# Atlanta Braves
#  (4)
#  @
#   Los Angeles Dodgers
#  (9)
#      Boxscore
#
#
# Washington Nationals
#  (3)
#  @
#   Milwaukee Brewers
#  (7)
#      Boxscore
#
#
#  Seattle Mariners
#  (10)
#  @
#   New York Yankees
#  (1)
#      Boxscore
#
#
# Cincinnati Reds
#  (4)
#  @
#   Oakland Athletics
#  (5)
#      Boxscore
#
#
#  Texas Rangers
#  (9)
#  @
#   Pittsburgh Pirates
#  (6)
#      Boxscore
#
#
# New York Mets
#  (2)
#  @
#   San Diego Padres
#  (3)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (5)
#  @
#   St. Louis Cardinals
#  (0)
#      Boxscore
#
#
#  Arizona D'Backs
#  (3)
#  @
#   Tampa Bay Rays
#  (2)
#      Boxscore
#
#
#  Minnesota Twins
#  (9)
#  @
#   Toronto Blue Jays
#  (1)
#      Boxscore
#
#     » 2019-05-08 Standings & Scores
#
# Atlanta Braves
#  (2)
#  @
#   Arizona D'Backs
#  (3)
#      Boxscore
#
#
# Miami Marlins
#  (1)
#  @
#   Chicago Cubs
#  (4)
#      Boxscore
#
#
# Chicago White Sox
#  (0)
#  @
#   Cleveland Indians
#  (5)
#      Boxscore
#
#
# San Francisco Giants
#  (11)
#  @
#   Colorado Rockies
#  (12)
#      Boxscore
#
#
#  Los Angeles Angels
#  (13)
#  @
#   Detroit Tigers
#  (0)
#      Boxscore
#
#
# Texas Rangers
#  (2)
#  @
#   Houston Astros
#  (4)
#      Boxscore
#
#
#  Washington Nationals
#  (6)
#  @
#   Los Angeles Dodgers
#  (0)
#      Boxscore
#
#
# Seattle Mariners
#  (1)
#  @
#   New York Yankees
#  (3)
#      Boxscore
#
#
#  Cincinnati Reds
#  (3)
#  @
#   Oakland Athletics
#  (0)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (4)
#  @
#   St. Louis Cardinals
#  (17)
#      Boxscore
#
#     » 2019-05-09 Standings & Scores
#
#  Atlanta Braves
#  (2)
#  @
#   Arizona D'Backs
#  (1)
#      Boxscore
#
#
#  Los Angeles Angels
#  (8)
#  @
#   Baltimore Orioles
#  (3)
#      Boxscore
#
#
# Seattle Mariners
#  (1)
#  @
#   Boston Red Sox
#  (14)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (7)
#  @
#   Chicago Cubs
#  (0)
#      Boxscore
#
#
# San Diego Padres
#  (2)
#  @
#   Colorado Rockies
#  (12)
#      Boxscore
#
#
# Texas Rangers
#  (0)
#  @
#   Houston Astros
#  (3)
#      Boxscore
#
#
# Philadelphia Phillies
#  (1)
#  @
#   Kansas City Royals
#  (5)
#      Boxscore
#
#
# Washington Nationals
#  (0)
#  @
#   Los Angeles Dodgers
#  (5)
#      Boxscore
#
#
# Detroit Tigers
#  (0)
#  @
#   Minnesota Twins
#  (6)
#      Boxscore
#
#
# Miami Marlins
#  (2)
#  @
#   New York Mets
#  (11)
#      Boxscore
#
#
# Cleveland Indians
#  (3)
#  @
#   Oakland Athletics
#  (4)
#      Boxscore
#
#
#  Cincinnati Reds
#  (7)
#  @
#   San Francisco Giants
#  (0)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (2)
#  @
#   St. Louis Cardinals
#  (1)
#      Boxscore
#
#
#  New York Yankees
#  (4)
#  @
#   Tampa Bay Rays
#  (3)
#      Boxscore
#
#
# Chicago White Sox
#  (3)
#  @
#   Toronto Blue Jays
#  (4)
#      Boxscore
#
#     » 2019-05-10 Standings & Scores
#
#  Atlanta Braves
#  (6)
#  @
#   Arizona D'Backs
#  (4)
#      Boxscore
#
#
#  Los Angeles Angels
#  (7)
#  @
#   Baltimore Orioles
#  (2)
#      Boxscore
#
#
# Seattle Mariners
#  (5)
#  @
#   Boston Red Sox
#  (9)
#      Boxscore
#
#
# Milwaukee Brewers
#  (1)
#  @
#   Chicago Cubs
#  (2)
#      Boxscore
#
#
#  San Diego Padres
#  (4)
#  @
#   Colorado Rockies
#  (3)
#      Boxscore
#
#
# Texas Rangers
#  (4)
#  @
#   Houston Astros
#  (11)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (7)
#  @
#   Kansas City Royals
#  (0)
#      Boxscore
#
#
#  Washington Nationals
#  (5)
#  @
#   Los Angeles Dodgers
#  (2)
#      Boxscore
#
#
#  Detroit Tigers
#  (5)
#  @
#   Minnesota Twins
#  (3)
#      Boxscore
#
#
# Detroit Tigers
#  (3)
#  @
#   Minnesota Twins
#  (8)
#      Boxscore
#
#
# Miami Marlins
#  (1)
#  @
#   New York Mets
#  (4)
#      Boxscore
#
#
# Cleveland Indians
#  (2)
#  @
#   Oakland Athletics
#  (3)
#      Boxscore
#
#
#  Cincinnati Reds
#  (5)
#  @
#   San Francisco Giants
#  (4)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (2)
#  @
#   St. Louis Cardinals
#  (1)
#      Boxscore
#
#
# New York Yankees
#  (2)
#  @
#   Tampa Bay Rays
#  (7)
#      Boxscore
#
#
#  Chicago White Sox
#  (7)
#  @
#   Toronto Blue Jays
#  (2)
#      Boxscore
#
#     » 2019-05-11 Standings & Scores
#
#  Atlanta Braves
#  (5)
#  @
#   Arizona D'Backs
#  (3)
#      Boxscore
#
#
# Los Angeles Angels
#  (1)
#  @
#   Baltimore Orioles
#  (5)
#      Boxscore
#
#
# Seattle Mariners
#  (2)
#  @
#   Boston Red Sox
#  (11)
#      Boxscore
#
#
# Milwaukee Brewers
#  (1)
#  @
#   Chicago Cubs
#  (4)
#      Boxscore
#
#
# San Diego Padres
#  (7)
#  @
#   Colorado Rockies
#  (10)
#      Boxscore
#
#
# Texas Rangers
#  (5)
#  @
#   Houston Astros
#  (15)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (6)
#  @
#   Kansas City Royals
#  (1)
#      Boxscore
#
#
# Washington Nationals
#  (0)
#  @
#   Los Angeles Dodgers
#  (6)
#      Boxscore
#
#
#  Detroit Tigers
#  (5)
#  @
#   Minnesota Twins
#  (3)
#      Boxscore
#
#
#  Cleveland Indians
#  (5)
#  @
#   Oakland Athletics
#  (3)
#      Boxscore
#
#
# Cincinnati Reds
#  (5)
#  @
#   San Francisco Giants
#  (6)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (10)
#  @
#   St. Louis Cardinals
#  (6)
#      Boxscore
#
#
#  New York Yankees
#  (7)
#  @
#   Tampa Bay Rays
#  (1)
#      Boxscore
#
#
#  Chicago White Sox
#  (5)
#  @
#   Toronto Blue Jays
#  (1)
#      Boxscore
#
#     » 2019-05-12 Standings & Scores
#
# Pittsburgh Pirates
#  (3)
#  @
#   Arizona D'Backs
#  (9)
#      Boxscore
#
#
# Cleveland Indians
#  (2)
#  @
#   Chicago White Sox
#  (5)
#      Boxscore
#
#
#  Houston Astros
#  (8)
#  @
#   Detroit Tigers
#  (1)
#      Boxscore
#
#
#  Los Angeles Angels
#  (5)
#  @
#   Minnesota Twins
#  (4)
#      Boxscore
#
#
# Milwaukee Brewers
#  (4)
#  @
#   Philadelphia Phillies
#  (7)
#      Boxscore
#
#
# Oakland Athletics
#  (5)
#  @
#   Seattle Mariners
#  (6)
#      Boxscore
#
#     » 2019-05-13 Standings & Scores
#
#  Pittsburgh Pirates
#  (6)
#  @
#   Arizona D'Backs
#  (2)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (14)
#  @
#   Atlanta Braves
#  (3)
#      Boxscore
#
#
#  Colorado Rockies
#  (5)
#  @
#   Boston Red Sox
#  (4)
#      Boxscore
#
#
#  Cleveland Indians
#  (9)
#  @
#   Chicago White Sox
#  (0)
#      Boxscore
#
#
#  Chicago Cubs
#  (3)
#  @
#   Cincinnati Reds
#  (1)
#      Boxscore
#
#
#  Houston Astros
#  (11)
#  @
#   Detroit Tigers
#  (4)
#      Boxscore
#
#
# Texas Rangers
#  (5)
#  @
#   Kansas City Royals
#  (11)
#      Boxscore
#
#
# San Diego Padres
#  (3)
#  @
#   Los Angeles Dodgers
#  (6)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (4)
#  @
#   Miami Marlins
#  (0)
#      Boxscore
#
#
# Los Angeles Angels
#  (3)
#  @
#   Minnesota Twins
#  (4)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (6)
#  @
#   Philadelphia Phillies
#  (1)
#      Boxscore
#
#
# Oakland Athletics
#  (3)
#  @
#   Seattle Mariners
#  (4)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (7)
#  @
#   San Francisco Giants
#  (3)
#      Boxscore
#
#
#  New York Mets
#  (6)
#  @
#   Washington Nationals
#  (2)
#      Boxscore
#
#     » 2019-05-14 Standings & Scores
#
# Pittsburgh Pirates
#  (1)
#  @
#   Arizona D'Backs
#  (11)
#      Boxscore
#
#
# St. Louis Cardinals
#  (0)
#  @
#   Atlanta Braves
#  (4)
#      Boxscore
#
#
# Colorado Rockies
#  (5)
#  @
#   Boston Red Sox
#  (6)
#      Boxscore
#
#
# Chicago Cubs
#  (5)
#  @
#   Cincinnati Reds
#  (6)
#      Boxscore
#
#
#  Houston Astros
#  (5)
#  @
#   Detroit Tigers
#  (1)
#      Boxscore
#
#
#  Texas Rangers
#  (6)
#  @
#   Kansas City Royals
#  (1)
#      Boxscore
#
#
# San Diego Padres
#  (0)
#  @
#   Los Angeles Dodgers
#  (2)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (1)
#  @
#   Miami Marlins
#  (0)
#      Boxscore
#
#
# Los Angeles Angels
#  (7)
#  @
#   Minnesota Twins
#  (8)
#      Boxscore
#
#
# Baltimore Orioles
#  (3)
#  @
#   New York Yankees
#  (5)
#      Boxscore
#
#
# Baltimore Orioles
#  (1)
#  @
#   New York Yankees
#  (3)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (5)
#  @
#   Philadelphia Phillies
#  (2)
#      Boxscore
#
#
# Toronto Blue Jays
#  (3)
#  @
#   San Francisco Giants
#  (4)
#      Boxscore
#
#
# New York Mets
#  (1)
#  @
#   Washington Nationals
#  (5)
#      Boxscore
#
#     » 2019-05-15 Standings & Scores
#
# St. Louis Cardinals
#  (2)
#  @
#   Atlanta Braves
#  (10)
#      Boxscore
#
#
# Toronto Blue Jays
#  (2)
#  @
#   Chicago White Sox
#  (4)
#      Boxscore
#
#
# Chicago Cubs
#  (2)
#  @
#   Cincinnati Reds
#  (4)
#      Boxscore
#
#
# Baltimore Orioles
#  (7)
#  @
#   Cleveland Indians
#  (14)
#      Boxscore
#
#
#  Oakland Athletics
#  (17)
#  @
#   Detroit Tigers
#  (3)
#      Boxscore
#
#
#  Texas Rangers
#  (16)
#  @
#   Kansas City Royals
#  (1)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (11)
#  @
#   Philadelphia Phillies
#  (3)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (3)
#  @
#   San Diego Padres
#  (4)
#      Boxscore
#
#
#  Minnesota Twins
#  (11)
#  @
#   Seattle Mariners
#  (6)
#      Boxscore
#
#
# New York Mets
#  (6)
#  @
#   Washington Nationals
#  (7)
#      Boxscore
#
#     » 2019-05-16 Standings & Scores
#
# Kansas City Royals
#  (2)
#  @
#   Los Angeles Angels
#  (5)
#      Boxscore
#
#
# San Francisco Giants
#  (0)
#  @
#   Arizona D'Backs
#  (7)
#      Boxscore
#
#
# Milwaukee Brewers
#  (8)
#  @
#   Atlanta Braves
#  (12)
#      Boxscore
#
#
#  Houston Astros
#  (3)
#  @
#   Boston Red Sox
#  (1)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (10)
#  @
#   Chicago White Sox
#  (2)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (6)
#  @
#   Cincinnati Reds
#  (0)
#      Boxscore
#
#
#  Baltimore Orioles
#  (5)
#  @
#   Cleveland Indians
#  (1)
#      Boxscore
#
#
#  Oakland Athletics
#  (7)
#  @
#   Detroit Tigers
#  (2)
#      Boxscore
#
#
# New York Mets
#  (6)
#  @
#   Miami Marlins
#  (8)
#      Boxscore
#
#
# Tampa Bay Rays
#  (3)
#  @
#   New York Yankees
#  (4)
#      Boxscore
#
#
# Colorado Rockies
#  (4)
#  @
#   Philadelphia Phillies
#  (5)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (5)
#  @
#   San Diego Padres
#  (3)
#      Boxscore
#
#
#  Minnesota Twins
#  (7)
#  @
#   Seattle Mariners
#  (1)
#      Boxscore
#
#
# St. Louis Cardinals
#  (3)
#  @
#   Texas Rangers
#  (7)
#      Boxscore
#
#
#  Chicago Cubs
#  (14)
#  @
#   Washington Nationals
#  (6)
#      Boxscore
#
#     » 2019-05-17 Standings & Scores
#
# Kansas City Royals
#  (3)
#  @
#   Los Angeles Angels
#  (6)
#      Boxscore
#
#
#  San Francisco Giants
#  (8)
#  @
#   Arizona D'Backs
#  (5)
#      Boxscore
#
#
# Milwaukee Brewers
#  (3)
#  @
#   Atlanta Braves
#  (4)
#      Boxscore
#
#
#  Houston Astros
#  (7)
#  @
#   Boston Red Sox
#  (3)
#      Boxscore
#
#
# Toronto Blue Jays
#  (1)
#  @
#   Chicago White Sox
#  (4)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (0)
#  @
#   Cincinnati Reds
#  (4)
#      Boxscore
#
#
# Baltimore Orioles
#  (1)
#  @
#   Cleveland Indians
#  (4)
#      Boxscore
#
#
#  Oakland Athletics
#  (4)
#  @
#   Detroit Tigers
#  (1)
#      Boxscore
#
#
# New York Mets
#  (0)
#  @
#   Miami Marlins
#  (2)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (2)
#  @
#   New York Yankees
#  (1)
#      Boxscore
#
#
# Colorado Rockies
#  (1)
#  @
#   Philadelphia Phillies
#  (2)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (7)
#  @
#   San Diego Padres
#  (2)
#      Boxscore
#
#
#  Minnesota Twins
#  (18)
#  @
#   Seattle Mariners
#  (4)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (8)
#  @
#   Texas Rangers
#  (2)
#      Boxscore
#
#
# Chicago Cubs
#  (2)
#  @
#   Washington Nationals
#  (5)
#      Boxscore
#
#     » 2019-05-18 Standings & Scores
#
#  Kansas City Royals
#  (5)
#  @
#   Los Angeles Angels
#  (1)
#      Boxscore
#
#
#  San Francisco Giants
#  (3)
#  @
#   Arizona D'Backs
#  (2)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (3)
#  @
#   Atlanta Braves
#  (2)
#      Boxscore
#
#
# Houston Astros
#  (3)
#  @
#   Boston Red Sox
#  (4)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (5)
#  @
#   Chicago White Sox
#  (2)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (8)
#  @
#   Cincinnati Reds
#  (3)
#      Boxscore
#
#
# Baltimore Orioles
#  (0)
#  @
#   Cleveland Indians
#  (10)
#      Boxscore
#
#
#  Oakland Athletics
#  (7)
#  @
#   Detroit Tigers
#  (3)
#      Boxscore
#
#
# New York Mets
#  (0)
#  @
#   Miami Marlins
#  (3)
#      Boxscore
#
#
# Tampa Bay Rays
#  (5)
#  @
#   New York Yankees
#  (13)
#      Boxscore
#
#
# Colorado Rockies
#  (5)
#  @
#   Philadelphia Phillies
#  (7)
#      Boxscore
#
#
#  Pittsburgh Pirates
#  (6)
#  @
#   San Diego Padres
#  (4)
#      Boxscore
#
#
# Minnesota Twins
#  (4)
#  @
#   Seattle Mariners
#  (7)
#      Boxscore
#
#
# St. Louis Cardinals
#  (4)
#  @
#   Texas Rangers
#  (5)
#      Boxscore
#
#
#  Chicago Cubs
#  (6)
#  @
#   Washington Nationals
#  (5)
#      Boxscore
#
#     » 2019-05-19 Standings & Scores
#
#  Minnesota Twins
#  (3)
#  @
#   Los Angeles Angels
#  (1)
#      Boxscore
#
#
#  New York Yankees
#  (10)
#  @
#   Baltimore Orioles
#  (7)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (5)
#  @
#   Chicago Cubs
#  (4)
#      Boxscore
#
#
#  Oakland Athletics
#  (6)
#  @
#   Cleveland Indians
#  (4)
#      Boxscore
#
#
# ...
#  (11)
#  @
#   Boston Red Sox
#  (3)
#      Boxscore
#
#
#  Cincinnati Reds
#  (3)
#  @
#   Chicago Cubs
#  (2)
#      Boxscore
#
#
# Detroit Tigers
#  (1)
#  @
#   Cleveland Indians
#  (2)
#      Boxscore
#
#
#  New York Mets
#  (7)
#  @
#   Colorado Rockies
#  (4)
#      Boxscore
#
#
# Texas Rangers
#  (2)
#  @
#   Houston Astros
#  (3)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (8)
#  @
#   Los Angeles Dodgers
#  (7)
#      Boxscore
#
#
#  San Diego Padres
#  (2)
#  @
#   Milwaukee Brewers
#  (1)
#      Boxscore
#
#
#  Chicago White Sox
#  (3)
#  @
#   Minnesota Twins
#  (1)
#      Boxscore
#
#
#  Los Angeles Angels
#  (3)
#  @
#   New York Yankees
#  (2)
#      Boxscore
#
#
# Kansas City Royals
#  (0)
#  @
#   Oakland Athletics
#  (1)
#      Boxscore
#
#
#  Seattle Mariners
#  (4)
#  @
#   Pittsburgh Pirates
#  (1)
#      Boxscore
#
#
# Washington Nationals
#  (1)
#  @
#   St. Louis Cardinals
#  (5)
#      Boxscore
#
#     » 2019-09-18 Standings & Scores
#
# Philadelphia Phillies
#  (4)
#  @
#   Atlanta Braves
#  (5)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (8)
#  @
#   Baltimore Orioles
#  (4)
#      Boxscore
#
#
# San Francisco Giants
#  (4)
#  @
#   Boston Red Sox
#  (5)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (5)
#  @
#   Chicago Cubs
#  (4)
#      Boxscore
#
#
# Detroit Tigers
#  (0)
#  @
#   Cleveland Indians
#  (7)
#      Boxscore
#
#
# San Diego Padres
#  (1)
#  @
#   Milwaukee Brewers
#  (5)
#      Boxscore
#
#
# Kansas City Royals
#  (5)
#  @
#   Minnesota Twins
#  (8)
#      Boxscore
#
#
# Los Angeles Angels
#  (1)
#  @
#   New York Yankees
#  (9)
#      Boxscore
#
#
#  Seattle Mariners
#  (6)
#  @
#   Pittsburgh Pirates
#  (5)
#      Boxscore
#
#     » 2019-09-19 Standings & Scores
#
# San Francisco Giants
#  (0)
#  @
#   Atlanta Braves
#  (6)
#      Boxscore
#
#
# Seattle Mariners
#  (3)
#  @
#   Baltimore Orioles
#  (5)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (2)
#  @
#   Chicago Cubs
#  (1)
#      Boxscore
#
#
#  New York Mets
#  (8)
#  @
#   Cincinnati Reds
#  (1)
#      Boxscore
#
#
# Philadelphia Phillies
#  (2)
#  @
#   Cleveland Indians
#  (5)
#      Boxscore
#
#
#  Chicago White Sox
#  (10)
#  @
#   Detroit Tigers
#  (1)
#      Boxscore
#
#
# Los Angeles Angels
#  (4)
#  @
#   Houston Astros
#  (6)
#      Boxscore
#
#
# Colorado Rockies
#  (5)
#  @
#   Los Angeles Dodgers
#  (12)
#      Boxscore
#
#
#  Washington Nationals
#  (6)
#  @
#   Miami Marlins
#  (4)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (1)
#  @
#   Milwaukee Brewers
#  (10)
#      Boxscore
#
#
# Kansas City Royals
#  (3)
#  @
#   Minnesota Twins
#  (4)
#      Boxscore
#
#
#  Toronto Blue Jays
#  (4)
#  @
#   New York Yankees
#  (3)
#      Boxscore
#
#
# Texas Rangers
#  (0)
#  @
#   Oakland Athletics
#  (8)
#      Boxscore
#
#
#  Arizona D'Backs
#  (9)
#  @
#   San Diego Padres
#  (0)
#      Boxscore
#
#
# Boston Red Sox
#  (4)
#  @
#   Tampa Bay Rays
#  (5)
#      Boxscore
#
#     » 2019-09-20 Standings & Scores
#
# San Francisco Giants
#  (1)
#  @
#   Atlanta Braves
#  (8)
#      Boxscore
#
#
#  Seattle Mariners
#  (7)
#  @
#   Baltimore Orioles
#  (6)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (9)
#  @
#   Chicago Cubs
#  (8)
#      Boxscore
#
#
# New York Mets
#  (2)
#  @
#   Cincinnati Reds
#  (3)
#      Boxscore
#
#
#  Philadelphia Phillies
#  (9)
#  @
#   Cleveland Indians
#  (4)
#      Boxscore
#
#
#  Chicago White Sox
#  (5)
#  @
#   Detroit Tigers
#  (3)
#      Boxscore
#
#
#  Los Angeles Angels
#  (8)
#  @
#   Houston Astros
#  (4)
#      Boxscore
#
#
#  Colorado Rockies
#  (4)
#  @
#   Los Angeles Dodgers
#  (2)
#      Boxscore
#
#
#  Washington Nationals
#  (10)
#  @
#   Miami Marlins
#  (4)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (1)
#  @
#   Milwaukee Brewers
#  (10)
#      Boxscore
#
#
#  Kansas City Royals
#  (12)
#  @
#   Minnesota Twins
#  (5)
#      Boxscore
#
#
# Toronto Blue Jays
#  (2)
#  @
#   New York Yankees
#  (7)
#      Boxscore
#
#
# Texas Rangers
#  (3)
#  @
#   Oakland Athletics
#  (12)
#      Boxscore
#
#
#  Arizona D'Backs
#  (4)
#  @
#   San Diego Padres
#  (2)
#      Boxscore
#
#
# Boston Red Sox
#  (4)
#  @
#   Tampa Bay Rays
#  (5)
#      Boxscore
#
#     » 2019-09-21 Standings & Scores
#
#  San Francisco Giants
#  (4)
#  @
#   Atlanta Braves
#  (1)
#      Boxscore
#
#
# Seattle Mariners
#  (1)
#  @
#   Baltimore Orioles
#  (2)
#      Boxscore
#
#
#  St. Louis Cardinals
#  (3)
#  @
#   Chicago Cubs
#  (2)
#      Boxscore
#
#
#  New York Mets
#  (6)
#  @
#   Cincinnati Reds
#  (3)
#      Boxscore
#
#
# Philadelphia Phillies
#  (1)
#  @
#   Cleveland Indians
#  (10)
#      Boxscore
#
#
# Chicago White Sox
#  (3)
#  @
#   Detroit Tigers
#  (6)
#      Boxscore
#
#
# Los Angeles Angels
#  (5)
#  @
#   Houston Astros
#  (13)
#      Boxscore
#
#
# Colorado Rockies
#  (4)
#  @
#   Los Angeles Dodgers
#  (7)
#      Boxscore
#
#
# Washington Nationals
#  (3)
#  @
#   Miami Marlins
#  (5)
#      Boxscore
#
#
# Pittsburgh Pirates
#  (3)
#  @
#   Milwaukee Brewers
#  (4)
#      Boxscore
#
#
# Kansas City Royals
#  (8)
#  @
#   Minnesota Twins
#  (12)
#      Boxscore
#
#
# Toronto Blue Jays
#  (3)
#  @
#   New York Yankees
#  (8)
#      Boxscore
#
#
#  Texas Rangers
#  (8)
#  @
#   Oakland Athletics
#  (3)
#      Boxscore
#
#
# Arizona D'Backs
#  (4)
#  @
#   San Diego Padres
#  (6)
#      Boxscore
#
#
#  Boston Red Sox
#  (7)
#  @
#   Tampa Bay Rays
#  (4)
#      Boxscore
#
#     » 2019-09-22 Standings & Scores
#
#  St. Louis Cardinals
#  (9)
#  @
#   Arizona D'Backs
#  (7)
#      Boxscore
#
#
#  Miami Marlins
#  (8)
#  @
#   New York Mets
#  (4)
#      Boxscore
#
#
# Boston Red Sox
#  (4)
#  @
#   Tampa Bay Rays
#  (7)
#      Boxscore
#
#
# Baltimore Orioles
#  (10)
#  @
#   Toronto Blue Jays
#  (11)
#      Boxscore
#
#
# Philadelphia Phillies
#  (2)
#  @
#   Washington Nationals
#  (7)
#      Boxscore
#
#     » 2019-09-23 Standings & Scores
#
# Oakland Athletics
#  (2)
#  @
#   Los Angeles Angels
#  (3)
#      Boxscore
#
#
# St. Louis Cardinals
#  (2)
#  @
#   Arizona D'Backs
#  (3)
#      Boxscore
#
#
#  Cleveland Indians
#  (11)
#  @
#   Chicago White Sox
#  (0)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (4)
#  @
#   Cincinnati Reds
#  (2)
#      Boxscore
#
#
#  Minnesota Twins
#  (4)
#  @
#   Detroit Tigers
#  (2)
#      Boxscore
#
#
# Atlanta Braves
#  (6)
#  @
#   Kansas City Royals
#  (9)
#      Boxscore
#
#
# Miami Marlins
#  (4)
#  @
#   New York Mets
#  (5)
#      Boxscore
#
#
# Chicago Cubs
#  (2)
#  @
#   Pittsburgh Pirates
#  (9)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (6)
#  @
#   San Diego Padres
#  (3)
#      Boxscore
#
#
#  Houston Astros
#  (3)
#  @
#   Seattle Mariners
#  (0)
#      Boxscore
#
#
#  Colorado Rockies
#  (8)
#  @
#   San Francisco Giants
#  (5)
#      Boxscore
#
#
# New York Yankees
#  (1)
#  @
#   Tampa Bay Rays
#  (2)
#      Boxscore
#
#
#  Boston Red Sox
#  (12)
#  @
#   Texas Rangers
#  (10)
#      Boxscore
#
#
#  Baltimore Orioles
#  (11)
#  @
#   Toronto Blue Jays
#  (4)
#      Boxscore
#
#
# Philadelphia Phillies
#  (1)
#  @
#   Washington Nationals
#  (4)
#      Boxscore
#
#
# Philadelphia Phillies
#  (5)
#  @
#   Washington Nationals
#  (6)
#      Boxscore
#
#     » 2019-09-24 Standings & Scores
#
#  Oakland Athletics
#  (3)
#  @
#   Los Angeles Angels
#  (2)
#      Boxscore
#
#
# St. Louis Cardinals
#  (7)
#  @
#   Arizona D'Backs
#  (9)
#      Boxscore
#
#
# Cleveland Indians
#  (3)
#  @
#   Chicago White Sox
#  (8)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (9)
#  @
#   Cincinnati Reds
#  (2)
#      Boxscore
#
#
#  Minnesota Twins
#  (5)
#  @
#   Detroit Tigers
#  (1)
#      Boxscore
#
#
#  Atlanta Braves
#  (10)
#  @
#   Kansas City Royals
#  (2)
#      Boxscore
#
#
# Miami Marlins
#  (3)
#  @
#   New York Mets
#  (10)
#      Boxscore
#
#
# Chicago Cubs
#  (2)
#  @
#   Pittsburgh Pirates
#  (4)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (6)
#  @
#   San Diego Padres
#  (4)
#      Boxscore
#
#
#  Houston Astros
#  (3)
#  @
#   Seattle Mariners
#  (0)
#      Boxscore
#
#
# Colorado Rockies
#  (1)
#  @
#   San Francisco Giants
#  (2)
#      Boxscore
#
#
# New York Yankees
#  (0)
#  @
#   Tampa Bay Rays
#  (4)
#      Boxscore
#
#
#  Boston Red Sox
#  (10)
#  @
#   Texas Rangers
#  (3)
#      Boxscore
#
#
# Baltimore Orioles
#  (2)
#  @
#   Toronto Blue Jays
#  (3)
#      Boxscore
#
#
# Philadelphia Phillies
#  (2)
#  @
#   Washington Nationals
#  (5)
#      Boxscore
#
#     » 2019-09-25 Standings & Scores
#
# Houston Astros
#  (3)
#  @
#   Los Angeles Angels
#  (4)
#      Boxscore
#
#
# Cleveland Indians
#  (0)
#  @
#   Chicago White Sox
#  (8)
#      Boxscore
#
#
#  Milwaukee Brewers
#  (5)
#  @
#   Cincinnati Reds
#  (3)
#      Boxscore
#
#
#  Minnesota Twins
#  (10)
#  @
#   Detroit Tigers
#  (4)
#      Boxscore
#
#
#  Miami Marlins
#  (4)
#  @
#   New York Mets
#  (2)
#      Boxscore
#
#
# Chicago Cubs
#  (5)
#  @
#   Pittsburgh Pirates
#  (9)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (1)
#  @
#   San Diego Padres
#  (0)
#      Boxscore
#
#
#  Oakland Athletics
#  (3)
#  @
#   Seattle Mariners
#  (1)
#      Boxscore
#
#
# Colorado Rockies
#  (3)
#  @
#   San Francisco Giants
#  (8)
#      Boxscore
#
#
# Boston Red Sox
#  (5)
#  @
#   Texas Rangers
#  (7)
#      Boxscore
#
#
# Philadelphia Phillies
#  (3)
#  @
#   Washington Nationals
#  (6)
#      Boxscore
#
#     » 2019-09-26 Standings & Scores
#
#  Houston Astros
#  (4)
#  @
#   Los Angeles Angels
#  (0)
#      Boxscore
#
#
# San Diego Padres
#  (3)
#  @
#   Arizona D'Backs
#  (6)
#      Boxscore
#
#
#  Baltimore Orioles
#  (4)
#  @
#   Boston Red Sox
#  (1)
#      Boxscore
#
#
# Milwaukee Brewers
#  (7)
#  @
#   Colorado Rockies
#  (11)
#      Boxscore
#
#
#  Minnesota Twins
#  (6)
#  @
#   Kansas City Royals
#  (2)
#      Boxscore
#
#
# Atlanta Braves
#  (2)
#  @
#   New York Mets
#  (4)
#      Boxscore
#
#
# Miami Marlins
#  (4)
#  @
#   Philadelphia Phillies
#  (5)
#      Boxscore
#
#
# Cincinnati Reds
#  (5)
#  @
#   Pittsburgh Pirates
#  (6)
#      Boxscore
#
#
# Oakland Athletics
#  (3)
#  @
#   Seattle Mariners
#  (4)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (9)
#  @
#   San Francisco Giants
#  (2)
#      Boxscore
#
#
#  Chicago Cubs
#  (8)
#  @
#   St. Louis Cardinals
#  (2)
#      Boxscore
#
#
#  New York Yankees
#  (14)
#  @
#   Texas Rangers
#  (7)
#      Boxscore
#
#
#  Tampa Bay Rays
#  (6)
#  @
#   Toronto Blue Jays
#  (2)
#      Boxscore
#
#
# Cleveland Indians
#  (2)
#  @
#   Washington Nationals
#  (8)
#      Boxscore
#
#     » 2019-09-27 Standings & Scores
#
#  Houston Astros
#  (6)
#  @
#   Los Angeles Angels
#  (3)
#      Boxscore
#
#
# San Diego Padres
#  (5)
#  @
#   Arizona D'Backs
#  (6)
#      Boxscore
#
#
#  Baltimore Orioles
#  (9)
#  @
#   Boston Red Sox
#  (4)
#      Boxscore
#
#
# Detroit Tigers
#  (1)
#  @
#   Chicago White Sox
#  (7)
#      Boxscore
#
#
#  Detroit Tigers
#  (4)
#  @
#   Chicago White Sox
#  (3)
#      Boxscore
#
#
# Milwaukee Brewers
#  (2)
#  @
#   Colorado Rockies
#  (3)
#      Boxscore
#
#
#  Minnesota Twins
#  (4)
#  @
#   Kansas City Royals
#  (3)
#      Boxscore
#
#
# Atlanta Braves
#  (0)
#  @
#   New York Mets
#  (3)
#      Boxscore
#
#
# Miami Marlins
#  (3)
#  @
#   Philadelphia Phillies
#  (9)
#      Boxscore
#
#
#  Cincinnati Reds
#  (4)
#  @
#   Pittsburgh Pirates
#  (2)
#      Boxscore
#
#
#  Oakland Athletics
#  (1)
#  @
#   Seattle Mariners
#  (0)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (2)
#  @
#   San Francisco Giants
#  (0)
#      Boxscore
#
#
#  Chicago Cubs
#  (8)
#  @
#   St. Louis Cardinals
#  (6)
#      Boxscore
#
#
# New York Yankees
#  (4)
#  @
#   Texas Rangers
#  (9)
#      Boxscore
#
#
# Tampa Bay Rays
#  (1)
#  @
#   Toronto Blue Jays
#  (4)
#      Boxscore
#
#
# Cleveland Indians
#  (7)
#  @
#   Washington Nationals
#  (10)
#      Boxscore
#
#     » 2019-09-28 Standings & Scores
#
#  Houston Astros
#  (8)
#  @
#   Los Angeles Angels
#  (5)
#      Boxscore
#
#
# San Diego Padres
#  (0)
#  @
#   Arizona D'Backs
#  (1)
#      Boxscore
#
#
# Baltimore Orioles
#  (4)
#  @
#   Boston Red Sox
#  (5)
#      Boxscore
#
#
# Detroit Tigers
#  (3)
#  @
#   Chicago White Sox
#  (5)
#      Boxscore
#
#
# Milwaukee Brewers
#  (3)
#  @
#   Colorado Rockies
#  (4)
#      Boxscore
#
#
# Minnesota Twins
#  (4)
#  @
#   Kansas City Royals
#  (5)
#      Boxscore
#
#
# Atlanta Braves
#  (6)
#  @
#   New York Mets
#  (7)
#      Boxscore
#
#
#  Miami Marlins
#  (4)
#  @
#   Philadelphia Phillies
#  (3)
#      Boxscore
#
#
#  Cincinnati Reds
#  (3)
#  @
#   Pittsburgh Pirates
#  (1)
#      Boxscore
#
#
# Oakland Athletics
#  (1)
#  @
#   Seattle Mariners
#  (3)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (9)
#  @
#   San Francisco Giants
#  (0)
#      Boxscore
#
#
# Chicago Cubs
#  (0)
#  @
#   St. Louis Cardinals
#  (9)
#      Boxscore
#
#
# New York Yankees
#  (1)
#  @
#   Texas Rangers
#  (6)
#      Boxscore
#
#
# Tampa Bay Rays
#  (3)
#  @
#   Toronto Blue Jays
#  (8)
#      Boxscore
#
#
# Cleveland Indians
#  (2)
#  @
#   Washington Nationals
#  (8)
#      Boxscore
#
#     » 2019-09-29 Standings & Scores
#
# Milwaukee Brewers
#  (3)
#  @
#   Washington Nationals
#  (4)
#      Boxscore
#
#     » 2019-10-01 Standings & Scores
#
#  Tampa Bay Rays
#  (5)
#  @
#   Oakland Athletics
#  (1)
#      Boxscore
#
#     » 2019-10-02 Standings & Scores
#
#  St. Louis Cardinals
#  (7)
#  @
#   Atlanta Braves
#  (6)
#      Boxscore
#
#
# Washington Nationals
#  (0)
#  @
#   Los Angeles Dodgers
#  (6)
#      Boxscore
#
#     » 2019-10-03 Standings & Scores
#
# St. Louis Cardinals
#  (0)
#  @
#   Atlanta Braves
#  (3)
#      Boxscore
#
#
# Tampa Bay Rays
#  (2)
#  @
#   Houston Astros
#  (6)
#      Boxscore
#
#
#  Washington Nationals
#  (4)
#  @
#   Los Angeles Dodgers
#  (2)
#      Boxscore
#
#
# Minnesota Twins
#  (4)
#  @
#   New York Yankees
#  (10)
#      Boxscore
#
#     » 2019-10-04 Standings & Scores
#
# Tampa Bay Rays
#  (1)
#  @
#   Houston Astros
#  (3)
#      Boxscore
#
#
# Minnesota Twins
#  (2)
#  @
#   New York Yankees
#  (8)
#      Boxscore
#
#     » 2019-10-05 Standings & Scores
#
#  Atlanta Braves
#  (3)
#  @
#   St. Louis Cardinals
#  (1)
#      Boxscore
#
#
#  Los Angeles Dodgers
#  (10)
#  @
#   Washington Nationals
#  (4)
#      Boxscore
#
#     » 2019-10-06 Standings & Scores
#
#  New York Yankees
#  (5)
#  @
#   Minnesota Twins
#  (1)
#      Boxscore
#
#
# Atlanta Braves
#  (4)
#  @
#   St. Louis Cardinals
#  (5)
#      Boxscore
#
#
# Houston Astros
#  (3)
#  @
#   Tampa Bay Rays
#  (10)
#      Boxscore
#
#
# Los Angeles Dodgers
#  (1)
#  @
#   Washington Nationals
#  (6)
#      Boxscore
#
#     » 2019-10-07 Standings & Scores
#
# Houston Astros
#  (1)
#  @
#   Tampa Bay Rays
#  (4)
#      Boxscore
#
#     » 2019-10-08 Standings & Scores
#
#  St. Louis Cardinals
#  (13)
#  @
#   Atlanta Braves
#  (1)
#      Boxscore
#
#
#  Washington Nationals
#  (7)
#  @
#   Los Angeles Dodgers
#  (3)
#      Boxscore
#
#     » 2019-10-09 Standings & Scores
#
# Tampa Bay Rays
#  (1)
#  @
#   Houston Astros
#  (6)
#      Boxscore
#
#     » 2019-10-10 Standings & Scores
#
#  Washington Nationals
#  (2)
#  @
#   St. Louis Cardinals
#  (0)
#      Boxscore
#
#     » 2019-10-11 Standings & Scores
#
#  New York Yankees
#  (7)
#  @
#   Houston Astros
#  (0)
#      Boxscore
#
#
#  Washington Nationals
#  (3)
#  @
#   St. Louis Cardinals
#  (1)
#      Boxscore
#
#     » 2019-10-12 Standings & Scores
#
# New York Yankees
#  (2)
#  @
#   Houston Astros
#  (3)
#      Boxscore
#
#     » 2019-10-13 Standings & Scores
#
# St. Louis Cardinals
#  (1)
#  @
#   Washington Nationals
#  (8)
#      Boxscore
#
#     » 2019-10-14 Standings & Scores
#
#  Houston Astros
#  (4)
#  @
#   New York Yankees
#  (1)
#      Boxscore
#
#
# St. Louis Cardinals
#  (4)
#  @
#   Washington Nationals
#  (7)
#      Boxscore
#
#     » 2019-10-15 Standings & Scores
#
#  Houston Astros
#  (8)
#  @
#   New York Yankees
#  (3)
#      Boxscore
#
#     » 2019-10-17 Standings & Scores
#
# Houston Astros
#  (1)
#  @
#   New York Yankees
#  (4)
#      Boxscore
#
#     » 2019-10-18 Standings & Scores
#
# New York Yankees
#  (4)
#  @
#   Houston Astros
#  (6)
#      Boxscore
#
#     » 2019-10-19 Standings & Scores
#
#  Washington Nationals
#  (5)
#  @
#   Houston Astros
#  (4)
#      Boxscore
#
#     » 2019-10-22 Standings & Scores
#
#  Washington Nationals
#  (12)
#  @
#   Houston Astros
#  (3)
#      Boxscore
#
#     » 2019-10-23 Standings & Scores
#
#  Houston Astros
#  (4)
#  @
#   Washington Nationals
#  (1)
#      Boxscore
#
#     » 2019-10-25 Standings & Scores
#
#  Houston Astros
#  (8)
#  @
#   Washington Nationals
#  (1)
#      Boxscore
#
#     » 2019-10-26 Standings & Scores
#
#  Houston Astros
#  (7)
#  @
#   Washington Nationals
#  (1)
#      Boxscore
#
#     » 2019-10-27 Standings & Scores
#
#  Washington Nationals
#  (7)
#  @
#   Houston Astros
#  (2)
#      Boxscore
#
#     » 2019-10-29 Standings & Scores
#
#  Washington Nationals
#  (6)
#  @
#   Houston Astros
#  (2)
#      Boxscore
#
#     » 2019-10-30 Standings & Scores
# 2019 MLB Season
# Minor Leagues
# Standings
# Schedule
# Fielding
# Batting
# Pitching
# Managers
# Fielding
# Batting
# Pitching
# Leaders & Awards
# Other
# Every Sports Reference Social Media Account
# Site Last Updated: Thursday, April 22,  1:58AM
#
# Question, Comment, Feedback, or Correction?
# Are you a Stathead, too? Subscribe to our Free Newsletter
# This Month in Sports ReferenceFind out when we add a feature or make a change
# Do you have a sports website? Or write about sports? We have tools and resources that can help you use sports data.  Find out more.
# All logos are the trademark & property of their owners and not Sports Reference LLC.  We present them here for purely educational purposes.
# 				Our reasoning for presenting offensive logos.
#
#
# 					Logos were compiled by the amazing SportsLogos.net.
#
# Copyright © 2000-2021 Sports Reference LLC. All rights reserved.
# Much of the play-by-play, game results, and transaction information both shown and used to create certain data sets was obtained free of charge from and is copyrighted by RetroSheet.
# Win Expectancy, Run Expectancy, and Leverage Index calculations provided by Tom Tango of InsideTheBook.com, and co-author of The Book: Playing the Percentages in Baseball.
# Total Zone Rating and initial framework for Wins above Replacement calculations provided by Sean Smith.
# Full-year historical Major League statistics provided by Pete Palmer and Gary Gillette of Hidden Game Sports.
#
# Some defensive statistics Copyright © Baseball Info Solutions, 2010-2021.
# Some high school data is courtesy David McWater.
# Many historical player head shots courtesy of David Davis. Many thanks to him. All images are property the copyright holder and are displayed here for informational purposes only.
# Thank you for letting us know.
